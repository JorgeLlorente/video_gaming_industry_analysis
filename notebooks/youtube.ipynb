# %% [markdown]
# ### Web Scraping Youtube

# %%
import requests
import re
import pandas as pd
import numpy as np
import random
import operator
from functools import reduce
from fuzzywuzzy import process, fuzz
import pickle
import sys
sys.path.append("../")

import src.support as sp


from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import ElementClickInterceptedException


from time import sleep

# %%
df_meta = pd.read_csv("../data/csv/all_games_unique.csv")
df_meta.head(1)
# Out:
#    Unnamed: 0    name  meta_score  user_review release_date
# 0           0  #DRIVE        69.0     6.990846   2021-02-16

# %%
df_twitch = pd.read_csv("../data/twitch/twitch.csv")
df_twitch.head(1)
# Out:
#    Unnamed: 0               game  watch_time_(hours)  stream_time_(hours)  \
# 0           0  League of Legends          88389049.0            1217250.0
#
#    peak_viewers  peak_channels  streamers  average_viewers  average_channels  \
# 0        553165           2945     113251           122933              1692
#
#    average_viewer_ratio       fecha
# 0                 72.61  2016-04-01

# %%
# We choose one month from twitch dataset to web scrape Youtube. Due to the limitation of queries, we'll
# study only 10 well-known games.
df_games = pd.read_csv("../data/twitch/twitch_raw_data/Most watched games on Twitch 2020 may - SullyGnome.csv")
games = list(df_games.Game.unique()[1:12])
df_study = pd.DataFrame(games)
df_study.rename({0: "name"}, axis = 1, inplace=True)

# We create a new dataframe to only have the release_date for each game. 
df_dates = df_study.merge(df_meta,how="inner", on="name")
df_dates.drop(["Unnamed: 0", "meta_score", "user_review"], axis=1,inplace=True)
df_dates.drop_duplicates(subset=["name"], inplace=True)
df_dates.reset_index(inplace=True)
df_dates.drop("index",axis=1, inplace=True)
df_dates
# Out:
#                                name release_date
# 0                 League of Legends   2009-10-27
# 1                          Fortnite   2017-07-25
# 2                Grand Theft Auto V   2013-09-17
# 3             Call of Duty: Warzone   2020-03-10
# 4  Counter-Strike: Global Offensive   2012-08-21
# 5                            Dota 2   2013-07-09
# 6                         Minecraft   2011-11-18
# 7                           FIFA 20   2019-09-24
# 8                 World of Warcraft   2004-11-23
# 9                      Apex Legends   2019-02-04

# %%
# We create a pickle file for this top games we will use later in the analysis.

with open ('../data/top10_games.pickle', "wb") as game:
    pickle.dump(games, game)

# %%
# We create a dict so each game will have a range of dates between their release_date (or a minimum of 2012) and 
# year 2022
dicc = {}
for i in range(df_dates.shape[0]):
    dicc[df_dates.loc[i].tolist()[0]] = pd.date_range(max(df_dates.loc[i].tolist()[1], '2012-01-01'),'2022-12-31', freq='MS').strftime("%Y-%m-%d").tolist()

# %%
# Now, we are going to create the query for Youtube. Thanks to advanced query formulas for Youtube, we can
# manipulate the query without the need of using the Youtube API.
# For the name of the game we are going to include in quotes "game" and "game gameplay"
# We are also going to look for videos that incluide "game" or "game gameplay" in the title of the video
# By last, we are going to include the date we created before in the dictionary, so each query will give us
# youtube videos that contain the 2 first things we asked for in the period of one month, starting in the
# release_date (or 2012) and ending in 2022-12-31.

research = []
for juego in dicc.keys():
    i = 1
    while (i<len(dicc[juego])):
        fecha_inicial = dicc[juego][i-1]
        fecha_final = dicc[juego][i]
        research.append(f'("{juego}" OR "{juego} gameplay" OR intitle:"{juego}" OR intitle:"{juego} gameplay") after:{fecha_inicial} before:{fecha_final}')
        i+=1
        if fecha_final == '2022-12-01':
            fecha_inicial = '2022-12-01'
            fecha_final = '2022-12-31'
            research.append(f'("{juego}" OR "{juego} gameplay" OR intitle:"{juego}" OR intitle:"{juego} gameplay") after:{fecha_inicial} before:{fecha_final}')
            i+=1

# %%
# For this list of Youtube queries, we have to make some changes so the query looks like exactly as the 
# url we have to insert in Youtube 

research_youtube = []
for busqueda in research:
    research_youtube.append(busqueda.replace(" ","+").replace(":","%3A"))
len(research_youtube)
# Out:
# 927

# %%
# Now we are able to use these urls to web scrape each youtube url finding the 100 youtube videos most viewed
# with the game name or the word "gameplay" within the video description or the title for each month of the year.

# This lines will search the youtube video ids in the html code of the web page.
# We will use them later when calling the Youtube API.

options = webdriver.ChromeOptions()

options.add_experimental_option("detach", True)
options.add_argument("--disable-extensions")
options.add_argument("--disable-notifications")
options.add_argument("--disable-Advertisement")
options.add_argument("--disable-popup-blocking")
options.add_argument("start-maximized")
options.add_argument("--disable-notifications")
options.add_argument("--ignore-certificate-errors")
options.add_argument("--no-sandbox")
options.add_argument("--log-level=3")
options.add_argument("--allow-running-insecure-content")
options.add_argument("--no-default-browser-check")
options.add_argument("--no-first-run")
options.add_argument("--no-proxy-server")
options.add_argument("--disable-blink-features=AutomationControlled")
exp_opt = [
    'enable-automation'
]

urls = []
for i in range(len(research_youtube)):
    try:
        driver = webdriver.Chrome(executable_path='chromedriver')
        url=f'https://www.youtube.com/results?search_query={research_youtube[i]}'
        driver.get(url)
        sleep(random.randint(1,3))
        driver.find_element("css selector", "#content > div.body.style-scope.ytd-consent-bump-v2-lightbox > div.eom-buttons.style-scope.ytd-consent-bump-v2-lightbox > div:nth-child(1) > ytd-button-renderer:nth-child(2) > yt-button-shape > button > yt-touch-feedback-shape > div > div.yt-spec-touch-feedback-shape__fill").click()
        sleep(random.randint(1,3))
        driver.find_element("css selector", "#container > ytd-toggle-button-renderer > yt-button-shape > button > yt-touch-feedback-shape > div > div.yt-spec-touch-feedback-shape__fill").click()
        sleep(random.randint(1,3))
        driver.find_element("xpath", '//*[@title="Ordenar por recuento de visualizaciones"]/yt-formatted-string').click()
        sleep(random.randint(1,3))
        driver.execute_script("window.scrollTo(0, 2000000);")
        sleep(random.randint(1,3))
        driver.execute_script("window.scrollTo(0, 2000000);")
        sleep(random.randint(1,3))
        driver.execute_script("window.scrollTo(0, 2000000);")
        sleep(random.randint(1,3))
        driver.execute_script("window.scrollTo(0, 2000000);")
        sleep(random.randint(1,3))
        data = driver.find_elements(By.ID, "video-title")

        for dato in data:
            if dato.get_attribute("aria-label") == None:
                pass
            else:
                urls.append(dato.get_attribute("aria-label"))
        driver.close()

    except NoSuchElementException:
        research_youtube.append(research_youtube[i])
        driver.close()
    except ElementClickInterceptedException:
        research_youtube.append(research_youtube[i])
        driver.close()

# %%
len(urls)
# Out:
# 84421

# %%
df = pd.DataFrame(urls)

# %%
df.to_csv("enlaces_youtube")

# %% [markdown]
# ### API Youtube

# %% [markdown]
# Now that we have all the urls, we are going to clean this csv so we only keep the ID for each video, needed
# for the queries in the Youtube API.

# %%
df = pd.read_csv("../data/youtube/enlaces_youtube")
df.drop("Unnamed: 0", axis=1, inplace=True)
df.columns = ["enlace"]
df.head(2)
# Out:
#                                         enlace
# 0  https://www.youtube.com/watch?v=B18qApcVCRg
# 1  https://www.youtube.com/watch?v=kNabvLyUXzI

# %%
df.value_counts().reset_index().head()
# Out:
#                                               enlace    0
# 0                                    cambio de juego  858
# 1  no hay data para: ("Grand+Theft+Auto+V"+OR+"Gr...    2
# 2        https://www.youtube.com/watch?v=cxGXf7rQGeo    2
# 3  no hay data para: ("FIFA+20"+OR+"FIFA+20+gamep...    2
# 4  no hay data para: ("Dota+2"+OR+"Dota+2+gamepla...    2

# %%
# We get rid of the rows we don't need and we create a new df for short videos because their url is different
# from usual videos.

lista_shorts = []
for i in range(df.shape[0]):
    if df.loc[i][0] == "cambio de juego":
        df.drop(i, inplace=True)
    elif df.loc[i][0].startswith("no hay"):
        df.drop(i, inplace=True)
    elif "shorts" in df.loc[i][0]:
        lista_shorts.append(df.loc[i][0])
        df.drop(i, inplace=True)

len(lista_shorts)
# Out:
# 1615

# %%
df.value_counts().reset_index().head(3)
# Out:
#                                         enlace  0
# 0  https://www.youtube.com/watch?v=xXKsaWeQt3c  2
# 1  https://www.youtube.com/watch?v=kA0Ywk7sQLg  2
# 2  https://www.youtube.com/watch?v=K2sOCo7dWqo  2

# %%
# We clean the urls from short videos

dff = pd.DataFrame(lista_shorts)
dff.columns = ["enlace"]
dff["enlace"] = dff["enlace"].apply(lambda x: x.strip("https://www.youtube.com/shorts/"))
dff.head(2)
# Out:
#         enlace
# 0  aGM_9wvWbUQ
# 1  Uwglp7WtHyM

# %%
df_final = pd.concat([df,dff], axis=0, ignore_index=True)
df_final.shape
# Out:
# (90699, 1)

# %%
# Now we can clean the other videos
df_final["enlace"] = df_final["enlace"].apply(lambda x: x.lstrip("https://www.youtube.com/watch?v="))
df_final.head(3)
# Out:
#         enlace
# 0  B18qApcVCRg
# 1  kNabvLyUXzI
# 2  No2MzRYs1-8

# %%
df_final.to_csv("codigos_YT")

# %%
df_final = pd.read_csv("../data/youtube/api/codigos_YT")

# %%
# During the web scraping, we haven't associated each url to their correspondant videogame. That's why we need 
# to manually group the different IDs.

df_lol_1 = df_final.loc[0:10001]
df_lol_2 = df_final.loc[10001:11557]
df_fortnite = df_final.loc[11557:17233]
df_gta = df_final.loc[17233:27356]
df_callofduty = df_final.loc[27356:30197]
df_csgo = df_final.loc[30197:41713]


list_fortnite = df_fortnite["enlace"].to_list()
list_lol_1 = df_lol_1["enlace"].to_list()
list_lol_2 = df_lol_2["enlace"].to_list()
list_callofduty = df_callofduty["enlace"].to_list()
list_gta = df_gta["enlace"].to_list()
list_csgo = df_csgo["enlace"].to_list()

# %%
# Now we can call the Youtube API with these IDs. For each day we have 10.000 queries for free. 

import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
sp.youtube(list_csgo, "Counter-Strike: Global Offensive", "csgo")
# Out:
# 403
# Ha ocurrido algo con el video 2onC_fZ_2E0
# 403
# Ha ocurrido algo con el video NTd_QRhKhg
# 403
# Ha ocurrido algo con el video frdhFPA3M-Q
# 403
# Ha ocurrido algo con el video qa454jRcba8
# 403
# Ha ocurrido algo con el video DFEPFiA-g
# 403
# Ha ocurrido algo con el video 75NJV2U1jLk
# 403
# Ha ocurrido algo con el video Utu83EvWdqE
# 403
# Ha ocurrido algo con el video jixQ7HRVs_k
# 403
# Ha ocurrido algo con el video G_rKC8FE6zM
# 403
# Ha ocurrido algo con el video lk000EoEffo
# 403
# Ha ocurrido algo con el video XZb5U5Zvgsw
# 403
# Ha ocurrido algo con el video Z6snRphhR98
# 403
# Ha ocurrido algo con el video 0cct0SSqEg
# 403
# Ha ocurrido algo con el video NuGtXTZ_bgo
# 403
# Ha ocurrido algo con el video XLKUcN29aJU
# 403
# Ha ocurrido algo con el video NPEEd8Vt4o
# 403
# Ha ocurrido algo con el video P4F7tKKVnYs
# 403
# Ha ocurrido algo con el video SjRE5-RMc
# 403
# Ha ocurrido algo con el video lW6_zI
# 403
# Ha ocurrido algo con el video Mld5XqyVfaM
# 403
# Ha ocurrido algo con el video _9HzDLtfGdc
# 403
# Ha ocurrido algo con el video -ZdRgJ3Ot0M
# 403
# Ha ocurrido algo con el video fc1mtDe2dD4
# 403
# Ha ocurrido algo con el video kO0e-pj-z0U
# 403
# Ha ocurrido algo con el video 4rGgBebO7j0
# 403
# Ha ocurrido algo con el video 0jAgfmUS4Kk
# 403
# Ha ocurrido algo con el video AuoLynNcHfY
# 403
# Ha ocurrido algo con el video L18Y0DGirnI
# 403
# Ha ocurrido algo con el video NqqUNxG72ok
# 403
# Ha ocurrido algo con el video 1Om8YfeWm5I
# 403
# Ha ocurrido algo con el video QpWlDLuxGYE
# 403
# Ha ocurrido algo con el video xCHBIydATs0
# 403
# Ha ocurrido algo con el video legXbhArsg
# 403
# Ha ocurrido algo con el video Xong54NKo9Q
# 403
# Ha ocurrido algo con el video 2o2LImwXJv0
# 403
# Ha ocurrido algo con el video RLyXkxXBXTU
# 403
# Ha ocurrido algo con el video 1uuUHPBzgMA
# 403
# Ha ocurrido algo con el video V2BPabKezJo
# 403
# Ha ocurrido algo con el video TJLsmmA0iY
# 403
# Ha ocurrido algo con el video 1Z1WfJiyC4M
# 403
# Ha ocurrido algo con el video iUAfjzQIihw
# 403
# Ha ocurrido algo con el video HZMZZ7z-QKI
# 403
# Ha ocurrido algo con el video ISw2EZ90tms
# 403
# Ha ocurrido algo con el video 74NU2uae6o
# 403
# Ha ocurrido algo con el video Xksln2LAqgc
# 403
# Ha ocurrido algo con el video gsWUIBJFSgk
# 403
# Ha ocurrido algo con el video XKXLDiSfmuA
# 403
# Ha ocurrido algo con el video EY0-FZzVTKQ
# 403
# Ha ocurrido algo con el video 6_pKsuyYJo
# 403
# Ha ocurrido algo con el video 4BfLlrJoblU
# 403
# Ha ocurrido algo con el video TFRFicVOGQo
# 403
# Ha ocurrido algo con el video JUFHz-Zju4w
# 403
# Ha ocurrido algo con el video EcwqQAvbJ8
# 403
# Ha ocurrido algo con el video AI8L6dLXx2k
# 403
# Ha ocurrido algo con el video 6rCmivnG79g
# 403
# Ha ocurrido algo con el video 5pbGlLFh8RM
# 403
# Ha ocurrido algo con el video nr4A1BVCW78
# 403
# Ha ocurrido algo con el video 31Ja0kwJ4ic
# 403
# Ha ocurrido algo con el video gKPrtWSV9ZE
# 403
# Ha ocurrido algo con el video 3SER32pYwQo
# 403
# Ha ocurrido algo con el video 5IhlH2Ob9E
# 403
# Ha ocurrido algo con el video nnolicJFEew
# 403
# Ha ocurrido algo con el video LA2ub5pAsLs
# 403
# Ha ocurrido algo con el video RR4PN-OYIUQ
# 403
# Ha ocurrido algo con el video Lb1WAHBH6tA
# 403
# Ha ocurrido algo con el video 8ejxGykMcT8
# 403
# Ha ocurrido algo con el video 6phBwqyJRK8
# 403
# Ha ocurrido algo con el video D_b3xuCHch8
# 403
# Ha ocurrido algo con el video xqsFT-TYAkw
# 403
# Ha ocurrido algo con el video RHEYCvlU9QQ
# 403
# Ha ocurrido algo con el video FdqLt7kxFvc
# 403
# Ha ocurrido algo con el video PZrYAjKcPII
# 403
# Ha ocurrido algo con el video NjwaWfwec8w
# 403
# Ha ocurrido algo con el video kCoj-U5rJ8
# 403
# Ha ocurrido algo con el video K14G0st5I8s
# 403
# Ha ocurrido algo con el video gbeLf5Pq7iM
# 403
# Ha ocurrido algo con el video CBDT7QfY2mw
# 403
# Ha ocurrido algo con el video DS3TDQClOKA
# 403
# Ha ocurrido algo con el video Wi6OK-antoQ
# 403
# Ha ocurrido algo con el video gojB2LNzwSg
# 403
# Ha ocurrido algo con el video LHBJ1g1bPtU
# 403
# Ha ocurrido algo con el video CuCIyISwo20
# 403
# Ha ocurrido algo con el video nUdFlYosN2U
# 403
# Ha ocurrido algo con el video 76c0fCzJAwg
# 403
# Ha ocurrido algo con el video TsKEzsQXMV8
# 403
# Ha ocurrido algo con el video qlqzRoa8Nw4
# 403
# Ha ocurrido algo con el video F1jeOb-QcQk
# 403
# Ha ocurrido algo con el video UDInyCc_YRk
# 403
# Ha ocurrido algo con el video JU0xBjJRLOI
# 403
# Ha ocurrido algo con el video FJYQUlAudI
# 403
# Ha ocurrido algo con el video 5fGsg5B-aos
# 403
# Ha ocurrido algo con el video MrV2-KKWidk
# 403
# Ha ocurrido algo con el video j3gmukb9kYk
# 403
# Ha ocurrido algo con el video qFHubwQGvs
# 403
# Ha ocurrido algo con el video Bqewn-tzl20
# 403
# Ha ocurrido algo con el video -muYCQoVBXw
# 403
# Ha ocurrido algo con el video jp2xBAD-g0
# 403
# Ha ocurrido algo con el video zIdgKY7DI
# 403
# Ha ocurrido algo con el video rMQ3pwjICoE
# 403
# Ha ocurrido algo con el video QCE-eS6Vimk
# 403
# Ha ocurrido algo con el video VKDYCNPZZ_k
# 403
# Ha ocurrido algo con el video 5UVDuNbJis
# 403
# Ha ocurrido algo con el video D7RG2UIZCk
# 403
# Ha ocurrido algo con el video 8gFGepjK3og
# 403
# Ha ocurrido algo con el video TROu0rQZzdI
# 403
# Ha ocurrido algo con el video A5i4Qvb9Ujg
# 403
# Ha ocurrido algo con el video 2ISqaE-IZes
# 403
# Ha ocurrido algo con el video dmz-ZfwPtCM
# 403
# Ha ocurrido algo con el video iEWGk-6ziI
# 403
# Ha ocurrido algo con el video lN2ahH8Riw
# 403
# Ha ocurrido algo con el video CAYTWe-fPWc
# 403
# Ha ocurrido algo con el video iclqJbcUs0
# 403
# Ha ocurrido algo con el video D0Ndor47XqE
# 403
# Ha ocurrido algo con el video 8sTcUCZlg
# 403
# Ha ocurrido algo con el video Ttseyc-bA1o
# 403
# Ha ocurrido algo con el video TBmoqxAXEj0
# 403
# Ha ocurrido algo con el video jEhaAXODwY
# 403
# Ha ocurrido algo con el video 826mhLbeeJw
# 403
# Ha ocurrido algo con el video N6kZYUgOE08
# 403
# Ha ocurrido algo con el video 8jfD4OeKe7Y
# 403
# Ha ocurrido algo con el video _Zr1YeaLOWU
# 403
# Ha ocurrido algo con el video 9xrlkqLHiyk
# 403
# Ha ocurrido algo con el video OHCi3HBvPCE
# 403
# Ha ocurrido algo con el video nZ_GvO2bS2c
# 403
# Ha ocurrido algo con el video nQyOkO42DsY
# 403
# Ha ocurrido algo con el video 3V0T325CIQQ
# 403
# Ha ocurrido algo con el video UqX0Kd7RJ6I
# 403
# Ha ocurrido algo con el video 7NMHVxdo2zE
# 403
# Ha ocurrido algo con el video 9nMQWeBpR7U
# 403
# Ha ocurrido algo con el video St8fS1erYro
# 403
# Ha ocurrido algo con el video 0an8Vek52g
# 403
# Ha ocurrido algo con el video D2V-Gn_iddI
# 403
# Ha ocurrido algo con el video Obvqlqw2gNc
# 403
# Ha ocurrido algo con el video YPlVjv-LhpQ
# 403
# Ha ocurrido algo con el video q7KUfqlsjUQ
# 403
# Ha ocurrido algo con el video FjLNdu_kJLs
# 403
# Ha ocurrido algo con el video dtcfP5AqmOw
# 403
# Ha ocurrido algo con el video OXoWnROQHOI
# 403
# Ha ocurrido algo con el video ncjhmqxP8A4
# 403
# Ha ocurrido algo con el video 1EIgyHa3bk
# 403
# Ha ocurrido algo con el video AmYpnlB4RrA
# 403
# Ha ocurrido algo con el video gAbdtBNuZ8
# 403
# Ha ocurrido algo con el video BpOS63MFMfY
# 403
# Ha ocurrido algo con el video GogO-87wNiY
# 403
# Ha ocurrido algo con el video fn_HeE5wDrA
# 403
# Ha ocurrido algo con el video O-Xl6yslqms
# 403
# Ha ocurrido algo con el video HgqLDkwFKAQ
# 403
# Ha ocurrido algo con el video QFnmS9JVyXU
# 403
# Ha ocurrido algo con el video HtSPDRmns
# 403
# Ha ocurrido algo con el video HETALEKbGjo
# 403
# Ha ocurrido algo con el video Hnaxg-Wr54A
# 403
# Ha ocurrido algo con el video E4wVTxl6-vU
# 403
# Ha ocurrido algo con el video OO3JePgHXsc
# 403
# Ha ocurrido algo con el video lt2cPJ-8Wp4
# 403
# Ha ocurrido algo con el video j1sqlGxM7Yo
# 403
# Ha ocurrido algo con el video EszTmpEfPy0
# 403
# Ha ocurrido algo con el video ZjhatI0lqDU
# 403
# Ha ocurrido algo con el video k3hzGsqrKOY
# 403
# Ha ocurrido algo con el video gIWgdz0brnA
# 403
# Ha ocurrido algo con el video 90zdWQByIqA
# 403
# Ha ocurrido algo con el video dbNddL03Jbk
# 403
# Ha ocurrido algo con el video 9idvAzz0mg
# 403
# Ha ocurrido algo con el video Q97w4wVmbFE
# 403
# Ha ocurrido algo con el video FfJI07nA
# 403
# Ha ocurrido algo con el video NOht4jmavs
# 403
# Ha ocurrido algo con el video FXVWCY0gpw
# 403
# Ha ocurrido algo con el video CdTEvw1IJZs
# 403
# Ha ocurrido algo con el video FfF_-eZ1Urc
# 403
# Ha ocurrido algo con el video PXuak3SbC18
# 403
# Ha ocurrido algo con el video 5F_LL6QN2jw
# 403
# Ha ocurrido algo con el video DxwEJnz00OY
# 403
# Ha ocurrido algo con el video RY4R7Ak8pRU
# 403
# Ha ocurrido algo con el video J8nrYllrvJY
# 403
# Ha ocurrido algo con el video SILcde-2xI
# 403
# Ha ocurrido algo con el video Uqvhw_tGmQ
# 403
# Ha ocurrido algo con el video --JIRJMmYGg
# 403
# Ha ocurrido algo con el video Q4hTeN38PMI
# 403
# Ha ocurrido algo con el video QO4xADKDnT4
# 403
# Ha ocurrido algo con el video CHIH3_NP_Vo
# 403
# Ha ocurrido algo con el video 8oozdSyQLU
# 403
# Ha ocurrido algo con el video S5vVRDmvI
# 403
# Ha ocurrido algo con el video -U0md8geY38
# 403
# Ha ocurrido algo con el video HfKad0l7X2A
# 403
# Ha ocurrido algo con el video 9iFq4qm_A2k
# 403
# Ha ocurrido algo con el video C3qtmd7NXI
# 403
# Ha ocurrido algo con el video Og-zP3Jup40
# 403
# Ha ocurrido algo con el video 6fiDiRBvuVI
# 403
# Ha ocurrido algo con el video IvYRUGYYlx0
# 403
# Ha ocurrido algo con el video _wfih_UmFks
# 403
# Ha ocurrido algo con el video zOKpAwYXzYM
# 403
# Ha ocurrido algo con el video qM3tcexiCU
# 403
# Ha ocurrido algo con el video k1Pga6L92mg
# 403
# Ha ocurrido algo con el video 1fjQvX8_u0
# 403
# Ha ocurrido algo con el video n-8Gk4bPfzk
# 403
# Ha ocurrido algo con el video YaAM_7RDdsM
# 403
# Ha ocurrido algo con el video ExN7BnK2Mpk
# 403
# Ha ocurrido algo con el video d61ZwszJemw
# 403
# Ha ocurrido algo con el video LAV92BGiAA0
# 403
# Ha ocurrido algo con el video SgHhbO5jinA
# 403
# Ha ocurrido algo con el video kVSU9SfgNE
# 403
# Ha ocurrido algo con el video 9DHR049FGr8
# 403
# Ha ocurrido algo con el video xoIlAyKnyG8
# 403
# Ha ocurrido algo con el video 0Lzk2H_d_8
# 403
# Ha ocurrido algo con el video i5zdSFGuXWM
# 403
# Ha ocurrido algo con el video KNwjALYvk90
# 403
# Ha ocurrido algo con el video 2_fPkU_g__c
# 403
# Ha ocurrido algo con el video V2It1PKrggI
# 403
# Ha ocurrido algo con el video LnsbAKMsBEY
# 403
# Ha ocurrido algo con el video gYPir1JLFU
# 403
# Ha ocurrido algo con el video MmI_cLpNAFM
# 403
# Ha ocurrido algo con el video Vg9FztD5LMk
# 403
# Ha ocurrido algo con el video Id1gCnjY3o8
# 403
# Ha ocurrido algo con el video P-ICwShoKCE
# 403
# Ha ocurrido algo con el video ShwJ3tT2BDY
# 403
# Ha ocurrido algo con el video dJa9X3oz3QY
# 403
# Ha ocurrido algo con el video iMKUmrrhK_k
# 403
# Ha ocurrido algo con el video gtD20SaCdok
# 403
# Ha ocurrido algo con el video q85fXnX7dLU
# 403
# Ha ocurrido algo con el video qI7ZfUXQI2o
# 403
# Ha ocurrido algo con el video JmUQo9yr1lo
# 403
# Ha ocurrido algo con el video -KotiHE9Inw
# 403
# Ha ocurrido algo con el video jIG5oDXJ4CY
# 403
# Ha ocurrido algo con el video Pm_9GLCghbA
# 403
# Ha ocurrido algo con el video -HH9enlwVQY
# 403
# Ha ocurrido algo con el video 2dc4fUbRA_w
# 403
# Ha ocurrido algo con el video TZptGQ0MXBk
# 403
# Ha ocurrido algo con el video FtVm8pshG08
# 403
# Ha ocurrido algo con el video glkNS19sIs
# 403
# Ha ocurrido algo con el video d_npdSyq88s
# 403
# Ha ocurrido algo con el video 6ybJgYtGA9M
# 403
# Ha ocurrido algo con el video 82pE3VIE8fs
# 403
# Ha ocurrido algo con el video Io5u4ZHdGFY
# 403
# Ha ocurrido algo con el video k4u0awMnQA
# 403
# Ha ocurrido algo con el video UX_plf65OYU
# 403
# Ha ocurrido algo con el video EhVj-Zp9M_g
# 403
# Ha ocurrido algo con el video z8nZQwCtZY
# 403
# Ha ocurrido algo con el video WLQzi98mHwQ
# 403
# Ha ocurrido algo con el video 7BlGyhP4MSk
# 403
# Ha ocurrido algo con el video 7pfxDvRnU8o
# 403
# Ha ocurrido algo con el video 6npUR8Zfv9o
# 403
# Ha ocurrido algo con el video -ESFr4zy2xM
# 403
# Ha ocurrido algo con el video _HREhElUpx4
# 403
# Ha ocurrido algo con el video z2YbdtugqF0
# 403
# Ha ocurrido algo con el video 2mUcp_DL_hw
# 403
# Ha ocurrido algo con el video NyYMt5qJCTY
# 403
# Ha ocurrido algo con el video Q3XPRZV6ltA
# 403
# Ha ocurrido algo con el video _Gyr8eENH2Q
# 403
# Ha ocurrido algo con el video N7PXtoXj4Ms
# 403
# Ha ocurrido algo con el video jZZRXbX0VKI
# 403
# Ha ocurrido algo con el video 6sHNHD3iC4
# 403
# Ha ocurrido algo con el video 2HVesOfE0
# 403
# Ha ocurrido algo con el video 2MnuIZGJ20
# 403
# Ha ocurrido algo con el video 5l4LTkqVY6I
# 403
# Ha ocurrido algo con el video xaG1Zkb18
# 403
# Ha ocurrido algo con el video UqNC9ywrZyw
# 403
# Ha ocurrido algo con el video _vOnM_Y2-w
# 403
# Ha ocurrido algo con el video TKaDsUWUqhw
# 403
# Ha ocurrido algo con el video qLVZQuYk
# 403
# Ha ocurrido algo con el video FwcfQ4BDyQ
# 403
# Ha ocurrido algo con el video ApS--Jj2PSg
# 403
# Ha ocurrido algo con el video q2W_R8-f1ts
# 403
# Ha ocurrido algo con el video BoWdtnv-0B4
# 403
# Ha ocurrido algo con el video jrltoCvf1kE
# 403
# Ha ocurrido algo con el video -UigJ-a8WGQ
# 403
# Ha ocurrido algo con el video jCFJcp4soKY
# 403
# Ha ocurrido algo con el video jEhxodmGRF8
# 403
# Ha ocurrido algo con el video Lr8sC2Sm9es
# 403
# Ha ocurrido algo con el video ftn3gOoex_A
# 403
# Ha ocurrido algo con el video r0aIe6I4IC8
# 403
# Ha ocurrido algo con el video dQan1kDJNvA
# 403
# Ha ocurrido algo con el video RqIca3BPHD0
# 403
# Ha ocurrido algo con el video 3vZ-Bvrkp-I
# 403
# Ha ocurrido algo con el video iKV7g-lorZY
# 403
# Ha ocurrido algo con el video YsldbPcU9XI
# 403
# Ha ocurrido algo con el video PIUdYWkvKYM
# 403
# Ha ocurrido algo con el video QCkZ6QVdWro
# 403
# Ha ocurrido algo con el video QMJBbP7aOwE
# 403
# Ha ocurrido algo con el video I2eOCWo2ejU
# 403
# Ha ocurrido algo con el video I67Xv9rms
# 403
# Ha ocurrido algo con el video AMjFznuq21M
# 403
# Ha ocurrido algo con el video dSVQP3O7Ycg
# 403
# Ha ocurrido algo con el video rHT-Rao1o
# 403
# Ha ocurrido algo con el video guA6RMET9Wo
# 403
# Ha ocurrido algo con el video FuadJZOWbtI
# 403
# Ha ocurrido algo con el video VAhiURGOmuM
# 403
# Ha ocurrido algo con el video 0qc_QIx-9T0
# 403
# Ha ocurrido algo con el video B0jjcu8HAxo
# 403
# Ha ocurrido algo con el video E8ltIqBfw
# 403
# Ha ocurrido algo con el video kr0cAYBX66E
# 403
# Ha ocurrido algo con el video 6mHQK4BZn04
# 403
# Ha ocurrido algo con el video DbvfyLfoSDE
# 403
# Ha ocurrido algo con el video kQUy3iYJg
# 403
# Ha ocurrido algo con el video Bu80wFnKErg
# 403
# Ha ocurrido algo con el video 7HylXrZItS0
# 403
# Ha ocurrido algo con el video O2SGAaand3E
# 403
# Ha ocurrido algo con el video XbHPNGE2nI
# 403
# Ha ocurrido algo con el video Ro6QVhMHJg
# 403
# Ha ocurrido algo con el video rufu9jiq0Rs
# 403
# Ha ocurrido algo con el video GLzf8OfEos0
# 403
# Ha ocurrido algo con el video ipKQnfO78lc
# 403
# Ha ocurrido algo con el video UuIJaAX0uw
# 403
# Ha ocurrido algo con el video FupEajod1xY
# 403
# Ha ocurrido algo con el video Buq9IxQONK4
# 403
# Ha ocurrido algo con el video JgTMx30EaFQ
# 403
# Ha ocurrido algo con el video PUNpcyVzcyw
# 403
# Ha ocurrido algo con el video FQ-MpH8wboQ
# 403
# Ha ocurrido algo con el video IV88JmcFQs
# 403
# Ha ocurrido algo con el video Jhq2VnQn5Q4
# 403
# Ha ocurrido algo con el video FJIVYtY38Y
# 403
# Ha ocurrido algo con el video dNChHhH-3qk
# 403
# Ha ocurrido algo con el video EDxoocDl_nU
# 403
# Ha ocurrido algo con el video CSvWBXpX3fQ
# 403
# Ha ocurrido algo con el video nBb3su2Px-Q
# 403
# Ha ocurrido algo con el video KDF23lduSe4
# 403
# Ha ocurrido algo con el video E7CymwQnmOk
# 403
# Ha ocurrido algo con el video 1UfTR_0OpTY
# 403
# Ha ocurrido algo con el video XzuK__HJnmA
# 403
# Ha ocurrido algo con el video RBaPtl1c-XQ
# 403
# Ha ocurrido algo con el video kIon3wOhA8
# 403
# Ha ocurrido algo con el video jT7O-G8fJzM
# 403
# Ha ocurrido algo con el video kwd7ruaHRo
# 403
# Ha ocurrido algo con el video 8QXEFm_edYE
# 403
# Ha ocurrido algo con el video IViFJEFr624
# 403
# Ha ocurrido algo con el video 6D8IZVMm97g
# 403
# Ha ocurrido algo con el video lvXHwEVAMPw
# 403
# Ha ocurrido algo con el video lCkwVuufdFQ
# 403
# Ha ocurrido algo con el video r-Sons5xfg
# 403
# Ha ocurrido algo con el video fvoQAkQmUPk
# 403
# Ha ocurrido algo con el video nzRNZgGrwo
# 403
# Ha ocurrido algo con el video 61eg2mAI
# 403
# Ha ocurrido algo con el video 0SP-eELxA
# 403
# Ha ocurrido algo con el video NIlQanB2UkM
# 403
# Ha ocurrido algo con el video Wq4jRlybIE
# 403
# Ha ocurrido algo con el video rp3mIj51S8
# 403
# Ha ocurrido algo con el video 32woYc7qEG4
# 403
# Ha ocurrido algo con el video 7yxljUTT1Kg
# 403
# Ha ocurrido algo con el video gUU5P05nqjU
# 403
# Ha ocurrido algo con el video HsdQ9X-9d0
# 403
# Ha ocurrido algo con el video YhyZb6YKUGw
# 403
# Ha ocurrido algo con el video 3C3x4Ug6c04
# 403
# Ha ocurrido algo con el video qaVyagYnCug
# 403
# Ha ocurrido algo con el video BUBkuLH-Ww
# 403
# Ha ocurrido algo con el video 9xf1B0GhLSc
# 403
# Ha ocurrido algo con el video EAzYxVcoz2s
# 403
# Ha ocurrido algo con el video IGe62QmWXBI
# 403
# Ha ocurrido algo con el video f4HtcEny90U
# 403
# Ha ocurrido algo con el video 8GokCc5mVvc
# 403
# Ha ocurrido algo con el video PuHjicv-yZI
# 403
# Ha ocurrido algo con el video N0XxkTKwGLU
# 403
# Ha ocurrido algo con el video PZq_ysO2MF8
# 403
# Ha ocurrido algo con el video Ylx86gxIfzo
# 403
# Ha ocurrido algo con el video XzOusZ5j6Hs
# 403
# Ha ocurrido algo con el video qKXYE7w9Kyw
# 403
# Ha ocurrido algo con el video -QrUA6OqlaQ
# 403
# Ha ocurrido algo con el video lMABGlltCf8
# 403
# Ha ocurrido algo con el video 0v8SyfWtfFE
# 403
# Ha ocurrido algo con el video qT2p5nxMd3U
# 403
# Ha ocurrido algo con el video -452fjqTZ50
# 403
# Ha ocurrido algo con el video _1ZoI4Vcm8o
# 403
# Ha ocurrido algo con el video 6DJZGhCeV9A
# 403
# Ha ocurrido algo con el video g5hv5z1PcaI
# 403
# Ha ocurrido algo con el video YrtTTbkIFN0
# 403
# Ha ocurrido algo con el video 7sbu8l0C5UQ
# 403
# Ha ocurrido algo con el video CBVd0_JiY0
# 403
# Ha ocurrido algo con el video JcDbQGf40
# 403
# Ha ocurrido algo con el video Bggzaq8w8Fk
# 403
# Ha ocurrido algo con el video KlrZPgycOVo
# 403
# Ha ocurrido algo con el video jWmLm95GhJY
# 403
# Ha ocurrido algo con el video rMWdU-A38U
# 403
# Ha ocurrido algo con el video JnEKVKic0
# 403
# Ha ocurrido algo con el video M3bNmKFh3E4
# 403
# Ha ocurrido algo con el video Lw4GvXWrcgs
# 403
# Ha ocurrido algo con el video DM7aILWAJAU
# 403
# Ha ocurrido algo con el video UkJOWq7WExU
# 403
# Ha ocurrido algo con el video zEViphOd0hQ
# 403
# Ha ocurrido algo con el video 18l8U2WL_V8
# 403
# Ha ocurrido algo con el video _quSYRV6KJA
# 403
# Ha ocurrido algo con el video GyAUu0XS7H0
# 403
# Ha ocurrido algo con el video Ixgnq0LMho0
# 403
# Ha ocurrido algo con el video rWzAwSvGPg0
# 403
# Ha ocurrido algo con el video 6p0U28QGKxE
# 403
# Ha ocurrido algo con el video QI3lb05EzuM
# 403
# Ha ocurrido algo con el video qwcVwf2yew
# 403
# Ha ocurrido algo con el video VbR0JHOp8mw
# 403
# Ha ocurrido algo con el video 27oYOcbqY
# 403
# Ha ocurrido algo con el video K3U08RSALrk
# 403
# Ha ocurrido algo con el video dyGHg99CkA
# 403
# Ha ocurrido algo con el video D-yhVt5X52c
# 403
# Ha ocurrido algo con el video EXLXWCONLtU
# 403
# Ha ocurrido algo con el video XuIAtS8-HHk
# 403
# Ha ocurrido algo con el video q_O-os72gt8
# 403
# Ha ocurrido algo con el video qs_J1Qa0CPQ
# 403
# Ha ocurrido algo con el video nUrsMDEP2C4
# 403
# Ha ocurrido algo con el video 24cL6r63pI
# 403
# Ha ocurrido algo con el video RJHYohQdo5M
# 403
# Ha ocurrido algo con el video Xay9WAvy8v0
# 403
# Ha ocurrido algo con el video Olb331xjnrc
# 403
# Ha ocurrido algo con el video fJLw1iiXABo
# 403
# Ha ocurrido algo con el video I2PND_m9sqk
# 403
# Ha ocurrido algo con el video AcRD_PsCU_c
# 403
# Ha ocurrido algo con el video r9mVorhl554
# 403
# Ha ocurrido algo con el video YHeyoHujFOI
# 403
# Ha ocurrido algo con el video Ktzer4SscP8
# 403
# Ha ocurrido algo con el video 4yq_l7UzlKQ
# 403
# Ha ocurrido algo con el video l_jXnIdAo
# 403
# Ha ocurrido algo con el video gLcUEYyqYfY
# 403
# Ha ocurrido algo con el video NXyqgcSyMbs
# 403
# Ha ocurrido algo con el video QQjGOiqH8
# 403
# Ha ocurrido algo con el video r96JaSsGh2A
# 403
# Ha ocurrido algo con el video rWP51qP0AM
# 403
# Ha ocurrido algo con el video ktctJCEHw2M
# 403
# Ha ocurrido algo con el video I7dzoO8mcnM
# 403
# Ha ocurrido algo con el video MsCiBd_buM
# 403
# Ha ocurrido algo con el video 7hcK_anmKQ
# 403
# Ha ocurrido algo con el video nsS4sIL4Zf4
# 403
# Ha ocurrido algo con el video BwmFgNoCFN0
# 403
# Ha ocurrido algo con el video 7HBM4y8e304
# 403
# Ha ocurrido algo con el video kddXMuww9k
# 403
# Ha ocurrido algo con el video NQeUFdM7JTs
# 403
# Ha ocurrido algo con el video 17V-R9nYoHE
# 403
# Ha ocurrido algo con el video 4hsS1NMd0aE
# 403
# Ha ocurrido algo con el video QLI7iirL2-0
# 403
# Ha ocurrido algo con el video 2P4ST-y7Z4c
# 403
# Ha ocurrido algo con el video U0ijxwJGG2s
# 403
# Ha ocurrido algo con el video Kx54KixsXRY
# 403
# Ha ocurrido algo con el video OKGQeZITIEA
# 403
# Ha ocurrido algo con el video EDMgo5Heqlg
# 403
# Ha ocurrido algo con el video QRUyojQWASg
# 403
# Ha ocurrido algo con el video J5NRcRnH1kc
# 403
# Ha ocurrido algo con el video AJTiKOWvQk0
# 403
# Ha ocurrido algo con el video Pj3xUA76Qjs
# 403
# Ha ocurrido algo con el video jNsQfOgV0ZE
# 403
# Ha ocurrido algo con el video UmF6lrhkd5k
# 403
# Ha ocurrido algo con el video SpNAb-X5qw
# 403
# Ha ocurrido algo con el video 2BYg77um86w
# 403
# Ha ocurrido algo con el video jpVMSaimLU
# 403
# Ha ocurrido algo con el video 3c8cYbYL0K0
# 403
# Ha ocurrido algo con el video zat-m3A0fNc
# 403
# Ha ocurrido algo con el video 4MXJULyxWOc
# 403
# Ha ocurrido algo con el video qP66B0e_6pc
# 403
# Ha ocurrido algo con el video zXGKGK7-jE
# 403
# Ha ocurrido algo con el video K7KHKrX5fVg
# 403
# Ha ocurrido algo con el video SqsaJFy8ds
# 403
# Ha ocurrido algo con el video OWj5BiRSh84
# 403
# Ha ocurrido algo con el video JRgFKT4frDc
# 403
# Ha ocurrido algo con el video xrDpyHI4qsA
# 403
# Ha ocurrido algo con el video Dyg3HfFMMYc
# 403
# Ha ocurrido algo con el video J9tglN_Am_8
# 403
# Ha ocurrido algo con el video WrUz2d_otqs
# 403
# Ha ocurrido algo con el video W1E14XKNY
# 403
# Ha ocurrido algo con el video A7ZH4zct1oE
# 403
# Ha ocurrido algo con el video JPpyZDs1wyc
# 403
# Ha ocurrido algo con el video UV0e5wwMG18
# 403
# Ha ocurrido algo con el video 4oSexRfnOIA
# 403
# Ha ocurrido algo con el video 0BUUavsl1uU
# 403
# Ha ocurrido algo con el video JLJu9rchAho
# 403
# Ha ocurrido algo con el video YF4XvY6QLhQ
# 403
# Ha ocurrido algo con el video -zr1rlSiY5A
# 403
# Ha ocurrido algo con el video JO_A24iV3Uk
# 403
# Ha ocurrido algo con el video UHjwS_w0ZJA
# 403
# Ha ocurrido algo con el video Xs72pethHjs
# 403
# Ha ocurrido algo con el video E5uIwsCPF8
# 403
# Ha ocurrido algo con el video iEfQtSx0EXg
# 403
# Ha ocurrido algo con el video jj3mmmEecNM
# 403
# Ha ocurrido algo con el video DRCtDP85CM
# 403
# Ha ocurrido algo con el video FglQ6x-bwPI
# 403
# Ha ocurrido algo con el video 7mklGzipsxk
# 403
# Ha ocurrido algo con el video d06lr2dE0ao
# 403
# Ha ocurrido algo con el video _LP1t-LDdMY
# 403
# Ha ocurrido algo con el video VbYHPrpNnzc
# 403
# Ha ocurrido algo con el video RaAeZllCYIE
# 403
# Ha ocurrido algo con el video 61nzg43QtSI
# 403
# Ha ocurrido algo con el video A4cVN29f-TY
# 403
# Ha ocurrido algo con el video 9hvFU6XcWLk
# 403
# Ha ocurrido algo con el video dbLcqawwuAU
# 403
# Ha ocurrido algo con el video JT6c11hQTno
# 403
# Ha ocurrido algo con el video j1SvaWDhe6Y
# 403
# Ha ocurrido algo con el video O7JcSM455to
# 403
# Ha ocurrido algo con el video lrljox37jAk
# 403
# Ha ocurrido algo con el video -rJbx98R_Bw
# 403
# Ha ocurrido algo con el video O1T49lGEEE8
# 403
# Ha ocurrido algo con el video -rY1sqAfYgM
# 403
# Ha ocurrido algo con el video Db2OFUpbE
# 403
# Ha ocurrido algo con el video Q9C_FOfII0
# 403
# Ha ocurrido algo con el video deASGcvxCrk
# 403
# Ha ocurrido algo con el video 7uRNwURNeV0
# 403
# Ha ocurrido algo con el video n95IDOP1fNY
# 403
# Ha ocurrido algo con el video ZLDvUp3yvlI
# 403
# Ha ocurrido algo con el video WfpDl-RZOdM
# 403
# Ha ocurrido algo con el video N3LtCgXHhGI
# 403
# Ha ocurrido algo con el video 1w-X4ki_RBs
# 403
# Ha ocurrido algo con el video _NXY5qbX0ig
# 403
# Ha ocurrido algo con el video 0DIY77s5vw
# 403
# Ha ocurrido algo con el video rEaPuKeejg
# 403
# Ha ocurrido algo con el video 1Opr9e-MJfE
# 403
# Ha ocurrido algo con el video _oezEwNrpKI
# 403
# Ha ocurrido algo con el video 8GcSjpPgF40
# 403
# Ha ocurrido algo con el video 4VB9ZtnET8
# 403
# Ha ocurrido algo con el video E81bppEhWuo
# 403
# Ha ocurrido algo con el video 9tLSRZITnyw
# 403
# Ha ocurrido algo con el video fBiZbm30LHg
# 403
# Ha ocurrido algo con el video Rgc4uQWfiXU
# 403
# Ha ocurrido algo con el video 7prMCpCwRRs
# 403
# Ha ocurrido algo con el video kP5DaDbmeqI
# 403
# Ha ocurrido algo con el video zX502hu9QDQ
# 403
# Ha ocurrido algo con el video qqBhybNef8
# 403
# Ha ocurrido algo con el video 2J2jhhDIMQ8
# 403
# Ha ocurrido algo con el video jxluWaU7HWo
# 403
# Ha ocurrido algo con el video K4g7ranRvNg
# 403
# Ha ocurrido algo con el video Z9nAPWpi6og
# 403
# Ha ocurrido algo con el video 8xRgpa4zqYI
# 403
# Ha ocurrido algo con el video IwY0-VgvtsE
# 403
# Ha ocurrido algo con el video Ziwsab3l0t4
# 403
# Ha ocurrido algo con el video YkdeMbRrbKM
# 403
# Ha ocurrido algo con el video lkau3-PAJ4w
# 403
# Ha ocurrido algo con el video HkJ9POm5T5Q
# 403
# Ha ocurrido algo con el video x8o4PPz-ENQ
# 403
# Ha ocurrido algo con el video 5zel6yycGts
# 403
# Ha ocurrido algo con el video N6264wsOLaA
# 403
# Ha ocurrido algo con el video ZogGW4jFuAg
# 403
# Ha ocurrido algo con el video 9IZ8jmmq3Rw
# 403
# Ha ocurrido algo con el video xXy8ARE0yok
# 403
# Ha ocurrido algo con el video neGFcEpjTY
# 403
# Ha ocurrido algo con el video iNtpQYLm_4c
# 403
# Ha ocurrido algo con el video HWg-gkKWfQU
# 403
# Ha ocurrido algo con el video JUWn9R58fLc
# 403
# Ha ocurrido algo con el video NAJzZKjECb8
# 403
# Ha ocurrido algo con el video PISn2RcWOo
# 403
# Ha ocurrido algo con el video DcncU_gFPE
# 403
# Ha ocurrido algo con el video W742lcTFZg
# 403
# Ha ocurrido algo con el video XYz5CXUlqQ
# 403
# Ha ocurrido algo con el video CgpZl5yBy_s
# 403
# Ha ocurrido algo con el video 8sgj6dSQyyY
# 403
# Ha ocurrido algo con el video q09jASUZpDk
# 403
# Ha ocurrido algo con el video ENVT-o2HXiI
# 403
# Ha ocurrido algo con el video Q4CgQdS2BY0
# 403
# Ha ocurrido algo con el video KWDYOTek-Ao
# 403
# Ha ocurrido algo con el video 2rKTN3kZWKI
# 403
# Ha ocurrido algo con el video PaSufFPuSw
# 403
# Ha ocurrido algo con el video di-YWlSbssw
# 403
# Ha ocurrido algo con el video CpJljyLhezo
# 403
# Ha ocurrido algo con el video XNaieesXl0
# 403
# Ha ocurrido algo con el video RnQJHZfU3lM
# 403
# Ha ocurrido algo con el video 8zry-O37pxs
# 403
# Ha ocurrido algo con el video GDGYShBH1xg
# 403
# Ha ocurrido algo con el video MdCUZimfS38
# 403
# Ha ocurrido algo con el video PL8NDB4ziL8
# 403
# Ha ocurrido algo con el video PE-D_2OSdu8
# 403
# Ha ocurrido algo con el video ByIeea1PYy0
# 403
# Ha ocurrido algo con el video ECb1RH95eYg
# 403
# Ha ocurrido algo con el video 48xTCK83CTI
# 403
# Ha ocurrido algo con el video XQeIW3Ri814
# 403
# Ha ocurrido algo con el video KghJUq8GhU
# 403
# Ha ocurrido algo con el video xhn3BufVJ6k
# 403
# Ha ocurrido algo con el video xYc4eWx8aY
# 403
# Ha ocurrido algo con el video 1p7cNajVM
# 403
# Ha ocurrido algo con el video x_QNCwh1Sw
# 403
# Ha ocurrido algo con el video 3BwkkJxSMs
# 403
# Ha ocurrido algo con el video XZTgKKSeY
# 403
# Ha ocurrido algo con el video Tx9SNkv8PDg
# 403
# Ha ocurrido algo con el video P8GgBZxtbBM
# 403
# Ha ocurrido algo con el video 2NCz8CqWVE
# 403
# Ha ocurrido algo con el video J4CurCxFrM
# 403
# Ha ocurrido algo con el video GsUuZOMjA68
# 403
# Ha ocurrido algo con el video VrKOFrKfFk
# 403
# Ha ocurrido algo con el video EdF38pVRlnE
# 403
# Ha ocurrido algo con el video VgbtejpYwtE
# 403
# Ha ocurrido algo con el video loDttmtEdiI
# 403
# Ha ocurrido algo con el video _HKv9VQwlYc
# 403
# Ha ocurrido algo con el video JpkukCiu5h8
# 403
# Ha ocurrido algo con el video nZkdMXL4fOY
# 403
# Ha ocurrido algo con el video 8PPOoGri2gQ
# 403
# Ha ocurrido algo con el video PYcMcZIouAw
# 403
# Ha ocurrido algo con el video Nzo6vD7oyhQ
# 403
# Ha ocurrido algo con el video OWAaCgJMxWI
# 403
# Ha ocurrido algo con el video G0v0j-vWnxU
# 403
# Ha ocurrido algo con el video ReFyg7w7LvA
# 403
# Ha ocurrido algo con el video 9sXi-2rl3A
# 403
# Ha ocurrido algo con el video PxOFq0wmWd4
# 403
# Ha ocurrido algo con el video 1Udm8-A-tL8
# 403
# Ha ocurrido algo con el video XRmkVt1cwa0
# 403
# Ha ocurrido algo con el video VsW4DXJC9U
# 403
# Ha ocurrido algo con el video 9N3R-e1tak
# 403
# Ha ocurrido algo con el video zCbEA0OngWU
# 403
# Ha ocurrido algo con el video rPpjUrd5c_c
# 403
# Ha ocurrido algo con el video ryZfOeZaYi8
# 403
# Ha ocurrido algo con el video FAi9Bje_Zh8
# 403
# Ha ocurrido algo con el video 0JBCrrAuWE
# 403
# Ha ocurrido algo con el video ihjVSuQLZ4
# 403
# Ha ocurrido algo con el video dobN2X1Eg3g
# 403
# Ha ocurrido algo con el video z9KawVBlCwc
# 403
# Ha ocurrido algo con el video YPoz3ev6G40
# 403
# Ha ocurrido algo con el video fdHIEPuc1iY
# 403
# Ha ocurrido algo con el video XqlzkpZmDSw
# 403
# Ha ocurrido algo con el video KG56-d2_e1s
# 403
# Ha ocurrido algo con el video -qRYgXzZTbE
# 403
# Ha ocurrido algo con el video WwJ5mUU0n9Q
# 403
# Ha ocurrido algo con el video P6krMEC6SMg
# 403
# Ha ocurrido algo con el video l8DdU6zn98
# 403
# Ha ocurrido algo con el video TE5wNPsKTM4
# 403
# Ha ocurrido algo con el video HCEIRvjhySo
# 403
# Ha ocurrido algo con el video -LHw1pjGmUU
# 403
# Ha ocurrido algo con el video 4AcM8SwPQ
# 403
# Ha ocurrido algo con el video n8PVVuNvz8
# 403
# Ha ocurrido algo con el video fYpVu-EBV0
# 403
# Ha ocurrido algo con el video NSrttNVA064
# 403
# Ha ocurrido algo con el video 6KXRa3mCbGk
# 403
# Ha ocurrido algo con el video xhd5C8ptDA8
# 403
# Ha ocurrido algo con el video iqO32eYT8o
# 403
# Ha ocurrido algo con el video UELraA3csI
# 403
# Ha ocurrido algo con el video CSjQFmv47Q
# 403
# Ha ocurrido algo con el video 45i9dECXA9U
# 403
# Ha ocurrido algo con el video Bq3BcnSjhz4
# 403
# Ha ocurrido algo con el video 2UAgcIHMV80
# 403
# Ha ocurrido algo con el video QPtl244Uu3o
# 403
# Ha ocurrido algo con el video RJT8uo98g7k
# 403
# Ha ocurrido algo con el video UJdQWLn00w
# 403
# Ha ocurrido algo con el video M4nTnR7ioMQ
# 403
# Ha ocurrido algo con el video 6eivn7tJ4kA
# 403
# Ha ocurrido algo con el video A2jmMsWMGFw
# 403
# Ha ocurrido algo con el video LNeoEtZ2v9I
# 403
# Ha ocurrido algo con el video NcvW2GYUXY
# 403
# Ha ocurrido algo con el video Ekp5wXFeOo
# 403
# Ha ocurrido algo con el video 4IGoH1qHADY
# 403
# Ha ocurrido algo con el video V2UhMbwU
# 403
# Ha ocurrido algo con el video E7zvWmIIU4
# 403
# Ha ocurrido algo con el video JyZ3V4W9a6Y
# 403
# Ha ocurrido algo con el video 1375Cp91WbI
# 403
# Ha ocurrido algo con el video EV2C13CHrCA
# 403
# Ha ocurrido algo con el video GKSvjrQ4DwM
# 403
# Ha ocurrido algo con el video KwSiHtMlGFU
# 403
# Ha ocurrido algo con el video icQnXoCS_o
# 403
# Ha ocurrido algo con el video 3BCINDbi1gQ
# 403
# Ha ocurrido algo con el video Kuax7ma0fp8
# 403
# Ha ocurrido algo con el video 5oxG_Re4sds
# 403
# Ha ocurrido algo con el video 2VfCbzFu2fM
# 403
# Ha ocurrido algo con el video Gi0T4du764w
# 403
# Ha ocurrido algo con el video XZcFRO5nxnA
# 403
# Ha ocurrido algo con el video V2wbucG3TEI
# 403
# Ha ocurrido algo con el video 708_5vi2OQE
# 403
# Ha ocurrido algo con el video M3oC4VM8pk
# 403
# Ha ocurrido algo con el video ncoYqD9-iZU
# 403
# Ha ocurrido algo con el video LBEUx9N1a8
# 403
# Ha ocurrido algo con el video IHKSafINl78
# 403
# Ha ocurrido algo con el video Pac5CeC2Pxo
# 403
# Ha ocurrido algo con el video fYMOCcjnHao
# 403
# Ha ocurrido algo con el video NjCkKPnTz4I
# 403
# Ha ocurrido algo con el video 8Syu8IaLj9Y
# 403
# Ha ocurrido algo con el video N3kV-E_Mp94
# 403
# Ha ocurrido algo con el video ze1zjm0NO_w
# 403
# Ha ocurrido algo con el video G-QVmECy8EE
# 403
# Ha ocurrido algo con el video Lfh22RljVSI
# 403
# Ha ocurrido algo con el video YX1cNwOos4
# 403
# Ha ocurrido algo con el video KrOeXWM-n-g
# 403
# Ha ocurrido algo con el video dt-xrc3VCOw
# 403
# Ha ocurrido algo con el video Ps44Vp9apx4
# 403
# Ha ocurrido algo con el video A63hIIj_zgE
# 403
# Ha ocurrido algo con el video 0ILPaRA_hxg
# 403
# Ha ocurrido algo con el video MEgNf2wEOQ
# 403
# Ha ocurrido algo con el video _g3xOBVGa8E
# 403
# Ha ocurrido algo con el video NZgoqYYtTEA
# 403
# Ha ocurrido algo con el video nqG5Ll3XQLg
# 403
# Ha ocurrido algo con el video SvkM88ZjOmo
# 403
# Ha ocurrido algo con el video AR3F-wkUr-g
# 403
# Ha ocurrido algo con el video nTjUMOks1gs
# 403
# Ha ocurrido algo con el video iE18FzI2U1s
# 403
# Ha ocurrido algo con el video BnmmN5Qp-o
# 403
# Ha ocurrido algo con el video NX3TG_9i_lw
# 403
# Ha ocurrido algo con el video qBcxhEh2Or8
# 403
# Ha ocurrido algo con el video ZH3E23UIoQ
# 403
# Ha ocurrido algo con el video xmzuevEmUEo
# 403
# Ha ocurrido algo con el video JRUT7N7OHhs
# 403
# Ha ocurrido algo con el video 1x4S5wQcYP8
# 403
# Ha ocurrido algo con el video 4ztL9S5vzjs
# 403
# Ha ocurrido algo con el video HgC0qp_FBCo
# 403
# Ha ocurrido algo con el video VzplX9MBPco
# 403
# Ha ocurrido algo con el video Mgqbq0HwFp4
# 403
# Ha ocurrido algo con el video zwrhNOiaQs
# 403
# Ha ocurrido algo con el video Dq8Xoi6_ORQ
# 403
# Ha ocurrido algo con el video K25Kl9N2Q6k
# 403
# Ha ocurrido algo con el video fteX7e-W8o
# 403
# Ha ocurrido algo con el video -E5obI8_Mvk
# 403
# Ha ocurrido algo con el video 6iYdgm1_mhs
# 403
# Ha ocurrido algo con el video 2Da_iWV5ts
# 403
# Ha ocurrido algo con el video 9LgzRM0gDQo
# 403
# Ha ocurrido algo con el video CkiZdTK_sCs
# 403
# Ha ocurrido algo con el video jzp7XM3vg
# 403
# Ha ocurrido algo con el video HRER12jsqXE
# 403
# Ha ocurrido algo con el video HX24IpQubOI
# 403
# Ha ocurrido algo con el video JEcxvM03JA
# 403
# Ha ocurrido algo con el video i1TThXEaCi0
# 403
# Ha ocurrido algo con el video MXVrQ_-qVIY
# 403
# Ha ocurrido algo con el video 5sYFkAJqo
# 403
# Ha ocurrido algo con el video jqLbyXttUrg
# 403
# Ha ocurrido algo con el video x0fFxsBo4
# 403
# Ha ocurrido algo con el video JxZktUY8fEA
# 403
# Ha ocurrido algo con el video n8TGWeZJLWc
# 403
# Ha ocurrido algo con el video d0aYl0wB20g
# 403
# Ha ocurrido algo con el video M3Z_rRPfjK4
# 403
# Ha ocurrido algo con el video z_JKn7Qe3Lk
# 403
# Ha ocurrido algo con el video l8q6Pv27I
# 403
# Ha ocurrido algo con el video 7fEUvzWl3Zk
# 403
# Ha ocurrido algo con el video W6lIpfjuA3Y
# 403
# Ha ocurrido algo con el video K4KuWPVFHko
# 403
# Ha ocurrido algo con el video WE-dJDmy6E
# 403
# Ha ocurrido algo con el video ZquQEPW24xE
# 403
# Ha ocurrido algo con el video KJoU6IA97-0
# 403
# Ha ocurrido algo con el video HZzfkpnOEI0
# 403
# Ha ocurrido algo con el video D1qxIVHhCY
# 403
# Ha ocurrido algo con el video 3AAvAUr0WA
# 403
# Ha ocurrido algo con el video r1LYwbakg2E
# 403
# Ha ocurrido algo con el video PbAik9ONRXw
# 403
# Ha ocurrido algo con el video L7Pb-9y8Zz0
# 403
# Ha ocurrido algo con el video OPylBEpM5CE
# 403
# Ha ocurrido algo con el video _vKsAws9W64
# 403
# Ha ocurrido algo con el video 1OvvEcy76aM
# 403
# Ha ocurrido algo con el video HE0vPPqhc
# 403
# Ha ocurrido algo con el video gsTLpRgk
# 403
# Ha ocurrido algo con el video 5SI1Osl6PAw
# 403
# Ha ocurrido algo con el video 2-_hJLbE0R0
# 403
# Ha ocurrido algo con el video -bdX0WlJv0E
# 403
# Ha ocurrido algo con el video 1tGFC4gY6c
# 403
# Ha ocurrido algo con el video xU2wJ5Kvpk
# 403
# Ha ocurrido algo con el video GYdAEBiOC_I
# 403
# Ha ocurrido algo con el video VW7em3zXgGA
# 403
# Ha ocurrido algo con el video lcXsPRiC8-E
# 403
# Ha ocurrido algo con el video rFCT_5ppx0s
# 403
# Ha ocurrido algo con el video G7nmN4JDAJc
# 403
# Ha ocurrido algo con el video O2CBMNjjOuU
# 403
# Ha ocurrido algo con el video A4zuRZDiqP8
# 403
# Ha ocurrido algo con el video QWQvhIXHVsI
# 403
# Ha ocurrido algo con el video OeBRRGjI
# 403
# Ha ocurrido algo con el video UcqJGVj-I
# 403
# Ha ocurrido algo con el video Qwsgi8ye8RM
# 403
# Ha ocurrido algo con el video RUq_4PpTS-M
# 403
# Ha ocurrido algo con el video 0Lul800qrM
# 403
# Ha ocurrido algo con el video n4Lg2vQEbE
# 403
# Ha ocurrido algo con el video 1Ec6d9bPs
# 403
# Ha ocurrido algo con el video RYIioyNxPBM
# 403
# Ha ocurrido algo con el video nGF4tduauzI
# 403
# Ha ocurrido algo con el video DR5yNhvzl2o
# 403
# Ha ocurrido algo con el video FoEVAGPu1N8
# 403
# Ha ocurrido algo con el video _vHF7OchKRA
# 403
# Ha ocurrido algo con el video BJJ1JwUwjM
# 403
# Ha ocurrido algo con el video j56bXOV7yn8
# 403
# Ha ocurrido algo con el video 0IIVrRG6cOQ
# 403
# Ha ocurrido algo con el video 2sPEo6V-v60
# 403
# Ha ocurrido algo con el video Y8iPh6658
# 403
# Ha ocurrido algo con el video iXFydVFF0Ps
# 403
# Ha ocurrido algo con el video GCguesshcnU
# 403
# Ha ocurrido algo con el video M8KeqxrFRbU
# 403
# Ha ocurrido algo con el video XOcNvxM
# 403
# Ha ocurrido algo con el video f2itYiY1dc
# 403
# Ha ocurrido algo con el video 16ag5zOIlfk
# 403
# Ha ocurrido algo con el video xgzI6I7SWEo
# 403
# Ha ocurrido algo con el video O3mPUO0XZ78
# 403
# Ha ocurrido algo con el video 0if5LPvmGmY
# 403
# Ha ocurrido algo con el video dEF4cryavU
# 403
# Ha ocurrido algo con el video -vg08KJFFLk
# 403
# Ha ocurrido algo con el video lFg7GFXBzFw
# 403
# Ha ocurrido algo con el video f1wya1CxFVQ
# 403
# Ha ocurrido algo con el video Cz_LDuqGqDA
# 403
# Ha ocurrido algo con el video 58KF2PE-xSo
# 403
# Ha ocurrido algo con el video Mchr34DqZ80
# 403
# Ha ocurrido algo con el video UGqTfWOwcW8
# 403
# Ha ocurrido algo con el video qYXCeearlSY
# 403
# Ha ocurrido algo con el video xcOH500j5QU
# 403
# Ha ocurrido algo con el video -kn2YGgD4KY
# 403
# Ha ocurrido algo con el video d0rfe0e5Y8s
# 403
# Ha ocurrido algo con el video 8FZgZaxq7DA
# 403
# Ha ocurrido algo con el video OalgFKbPHcg
# 403
# Ha ocurrido algo con el video 8fyesmvFedU
# 403
# Ha ocurrido algo con el video YthzF8DFauU
# 403
# Ha ocurrido algo con el video D0KA42crgwg
# 403
# Ha ocurrido algo con el video nom0fe0rqEk
# 403
# Ha ocurrido algo con el video YFzOQL8Ils
# 403
# Ha ocurrido algo con el video gbQm6oZXvQU
# 403
# Ha ocurrido algo con el video 5CH5H-iuuys
# 403
# Ha ocurrido algo con el video Eukp0LDAtK4
# 403
# Ha ocurrido algo con el video 2Gx8sdnJBs
# 403
# Ha ocurrido algo con el video XIguSo1Htw
# 403
# Ha ocurrido algo con el video UAafWj7eAk
# 403
# Ha ocurrido algo con el video WzcR-_W2BJw
# 403
# Ha ocurrido algo con el video 3nSLtm3xESw
# 403
# Ha ocurrido algo con el video SjUGxyGY8-c
# 403
# Ha ocurrido algo con el video PH0Ijw7CMUo
# 403
# Ha ocurrido algo con el video PRDmLbtD41U
# 403
# Ha ocurrido algo con el video Qot-Vfz_7eM
# 403
# Ha ocurrido algo con el video kQtKqK1fM6M
# 403
# Ha ocurrido algo con el video jLnAh-X-uDA
# 403
# Ha ocurrido algo con el video riICn2esJLA
# 403
# Ha ocurrido algo con el video YX3w8G-pTY
# 403
# Ha ocurrido algo con el video EEQA2pKKVwE
# 403
# Ha ocurrido algo con el video Umazm4-H-7w
# 403
# Ha ocurrido algo con el video 2dr92tKoHCo
# 403
# Ha ocurrido algo con el video NU863GxNh4
# 403
# Ha ocurrido algo con el video UarOKz9wVA
# 403
# Ha ocurrido algo con el video 0GcmO9ekWkY
# 403
# Ha ocurrido algo con el video X11yRtfL7Io
# 403
# Ha ocurrido algo con el video 13eYlLQrN5A
# 403
# Ha ocurrido algo con el video 6reqk17YOKI
# 403
# Ha ocurrido algo con el video JEmXJLY4eow
# 403
# Ha ocurrido algo con el video WPrk5VzJT8
# 403
# Ha ocurrido algo con el video -L0XYz_aCKQ
# 403
# Ha ocurrido algo con el video RujSzZ_HkY
# 403
# Ha ocurrido algo con el video _lUpgz3-6w
# 403
# Ha ocurrido algo con el video qZDVPKwa3Bo
# 403
# Ha ocurrido algo con el video ReoMZJuZCWk
# 403
# Ha ocurrido algo con el video lTObs2FVCLE
# 403
# Ha ocurrido algo con el video IeiYIRH_KaA
# 403
# Ha ocurrido algo con el video RIZQJubQk8Y
# 403
# Ha ocurrido algo con el video TokZHz0AR_w
# 403
# Ha ocurrido algo con el video xR5_MJzG6Fs
# 403
# Ha ocurrido algo con el video 6il7JfhwWNE
# 403
# Ha ocurrido algo con el video 7UPIZKQLdG4
# 403
# Ha ocurrido algo con el video NgKFARPz43k
# 403
# Ha ocurrido algo con el video UYlNDdpXzTU
# 403
# Ha ocurrido algo con el video CPSLW9TD4GI
# 403
# Ha ocurrido algo con el video 9Q3P8PVnu74
# 403
# Ha ocurrido algo con el video JkXk1qCzhbQ
# 403
# Ha ocurrido algo con el video 6ad0mRIz8
# 403
# Ha ocurrido algo con el video GWWCHIC5ltc
# 403
# Ha ocurrido algo con el video MiRJ1FKLiNs
# 403
# Ha ocurrido algo con el video 7WJU2uLHNIo
# 403
# Ha ocurrido algo con el video rT9vzhh2ImE
# 403
# Ha ocurrido algo con el video QbygSV4Mk
# 403
# Ha ocurrido algo con el video 65oNnoIMohU
# 403
# Ha ocurrido algo con el video BTS5r2uLic
# 403
# Ha ocurrido algo con el video xhB1Qlu8pA
# 403
# Ha ocurrido algo con el video lCeEPd3PJGU
# 403
# Ha ocurrido algo con el video 3BuY3B43LLo
# 403
# Ha ocurrido algo con el video UzGXHb-0KiA
# 403
# Ha ocurrido algo con el video q4IuCscEXkU
# 403
# Ha ocurrido algo con el video CqX13Z-GUZw
# 403
# Ha ocurrido algo con el video RUxGQLMiDgA
# 403
# Ha ocurrido algo con el video 1nlIgQxNIKE
# 403
# Ha ocurrido algo con el video 6Nfz9PeiWQ0
# 403
# Ha ocurrido algo con el video THXt8PSO4w
# 403
# Ha ocurrido algo con el video A8QF5AanB0
# 403
# Ha ocurrido algo con el video ISWu72J0j4
# 403
# Ha ocurrido algo con el video Ev5NyDoWIs
# 403
# Ha ocurrido algo con el video O5hNn1WjCLU
# 403
# Ha ocurrido algo con el video Y6Prt-Tecxs
# 403
# Ha ocurrido algo con el video rXDDHgwOCeo
# 403
# Ha ocurrido algo con el video FQ0_moHuYFo
# 403
# Ha ocurrido algo con el video 5a0u7KltLVg
# 403
# Ha ocurrido algo con el video 2O1_Sz41iEw
# 403
# Ha ocurrido algo con el video dkBu88aPC6c
# 403
# Ha ocurrido algo con el video 1kFDgDjAUE
# 403
# Ha ocurrido algo con el video kEI_Rxnbpkk
# 403
# Ha ocurrido algo con el video d9EcVYbBlCc
# 403
# Ha ocurrido algo con el video _qBHDQbGc
# 403
# Ha ocurrido algo con el video QM3tbmBRqDg
# 403
# Ha ocurrido algo con el video 5wTGPQC9wQ
# 403
# Ha ocurrido algo con el video J5QeL33284
# 403
# Ha ocurrido algo con el video IWBc9E5BEJs
# 403
# Ha ocurrido algo con el video LsaCPZxwEQ
# 403
# Ha ocurrido algo con el video 1_CWav7pnz8
# 403
# Ha ocurrido algo con el video IvExldfZPnw
# 403
# Ha ocurrido algo con el video -Ei0jbvEs4U
# 403
# Ha ocurrido algo con el video fPJPFibkup0
# 403
# Ha ocurrido algo con el video EbzMZtFHlYg
# 403
# Ha ocurrido algo con el video FSWLd4pZCaA
# 403
# Ha ocurrido algo con el video FUAKXY5yR50
# 403
# Ha ocurrido algo con el video -0ngQEK1zds
# 403
# Ha ocurrido algo con el video 6cXFTT2bMw4
# 403
# Ha ocurrido algo con el video CRM0FP8RpM
# 403
# Ha ocurrido algo con el video W6RlVX3O6FQ
# 403
# Ha ocurrido algo con el video 8v_okq2A7-E
# 403
# Ha ocurrido algo con el video 2uLA5RtZ4TE
# 403
# Ha ocurrido algo con el video SqOs6VVfGtw
# 403
# Ha ocurrido algo con el video Mgx0UJqfx8
# 403
# Ha ocurrido algo con el video XaKJGMYdpg
# 403
# Ha ocurrido algo con el video LsiSv5YSE4k
# 403
# Ha ocurrido algo con el video _ciqx5Q7TU
# 403
# Ha ocurrido algo con el video 6Z2gXb2zFH4
# 403
# Ha ocurrido algo con el video J24rOt0vNkU
# 403
# Ha ocurrido algo con el video nuv2TMdVvow
# 403
# Ha ocurrido algo con el video PSTR2AW2R9Y
# 403
# Ha ocurrido algo con el video RpX4NdFAbk
# 403
# Ha ocurrido algo con el video 0MY6dr0TtM
# 403
# Ha ocurrido algo con el video iyUnNNq294o
# 403
# Ha ocurrido algo con el video C0suE1RexLk
# 403
# Ha ocurrido algo con el video EU0gx5ipys
# 403
# Ha ocurrido algo con el video lZXnQkj0FQY
# 403
# Ha ocurrido algo con el video ZX9xtTV4AvA
# 403
# Ha ocurrido algo con el video NiB8sh_fzg4
# 403
# Ha ocurrido algo con el video K-Zp19JRfAY
# 403
# Ha ocurrido algo con el video AwGieXxNOgo
# 403
# Ha ocurrido algo con el video QOOkQGqC864
# 403
# Ha ocurrido algo con el video r28yvV8i38
# 403
# Ha ocurrido algo con el video U5r9hMbmi4
# 403
# Ha ocurrido algo con el video 0InPs7tAJ8g
# 403
# Ha ocurrido algo con el video iQdnWgEBJHs
# 403
# Ha ocurrido algo con el video SXaxvDxMQJs
# 403
# Ha ocurrido algo con el video xCq3wVh4JN8
# 403
# Ha ocurrido algo con el video GkXNM7mPTic
# 403
# Ha ocurrido algo con el video xZWwfhXgHIs
# 403
# Ha ocurrido algo con el video 9q1DCC16EhA
# 403
# Ha ocurrido algo con el video -2ErPJXTF80
# 403
# Ha ocurrido algo con el video V4dmMWT0nCM
# 403
# Ha ocurrido algo con el video -Nar2bZ59QY
# 403
# Ha ocurrido algo con el video AN4HJTcHbGs
# 403
# Ha ocurrido algo con el video 61_-u5Z-HzM
# 403
# Ha ocurrido algo con el video kOXgbBr_O9A
# 403
# Ha ocurrido algo con el video U3l2Z7unpo
# 403
# Ha ocurrido algo con el video IbTwd1RhVJs
# 403
# Ha ocurrido algo con el video 9ukGip57JUo
# 403
# Ha ocurrido algo con el video Px3QLNqy34
# 403
# Ha ocurrido algo con el video k4DKbDWv7lE
# 403
# Ha ocurrido algo con el video B9Ohi1Fi7_8
# 403
# Ha ocurrido algo con el video kS4W45RALvE
# 403
# Ha ocurrido algo con el video BJXcFcQHv4
# 403
# Ha ocurrido algo con el video UcUmPwoQwc0
# 403
# Ha ocurrido algo con el video l7UoxEYaQnk
# 403
# Ha ocurrido algo con el video i60VB5xglmk
# 403
# Ha ocurrido algo con el video NyVvKsy-ipw
# 403
# Ha ocurrido algo con el video FtB6mqq6JiQ
# 403
# Ha ocurrido algo con el video D483c2OsKzU
# 403
# Ha ocurrido algo con el video rbx_9taIe0U
# 403
# Ha ocurrido algo con el video PLmK_J-2U0w
# 403
# Ha ocurrido algo con el video 2FlAvo4DrrA
# 403
# Ha ocurrido algo con el video 7W32gnZ0xTo
# 403
# Ha ocurrido algo con el video -dArU9fp0GQ
# 403
# Ha ocurrido algo con el video gOR_UGHEnk8
# 403
# Ha ocurrido algo con el video Y_rKJdswoMI
# 403
# Ha ocurrido algo con el video GxbzFyBVd84
# 403
# Ha ocurrido algo con el video TyeWKjeCl4
# 403
# Ha ocurrido algo con el video na79Ts4qOU
# 403
# Ha ocurrido algo con el video r9wD7Zoo_0
# 403
# Ha ocurrido algo con el video k_X4ENEZWw
# 403
# Ha ocurrido algo con el video AdQlQk64RMk
# 403
# Ha ocurrido algo con el video 9T7FgtGw2G8
# 403
# Ha ocurrido algo con el video 8aoJFPJR2rw
# 403
# Ha ocurrido algo con el video 0M8K-w5tZCg
# 403
# Ha ocurrido algo con el video jVgjuNxVlo
# 403
# Ha ocurrido algo con el video G0McrpCUmzw
# 403
# Ha ocurrido algo con el video dNthKjgRDA
# 403
# Ha ocurrido algo con el video Jyr7RC52Abk
# 403
# Ha ocurrido algo con el video TewhUz7j4
# 403
# Ha ocurrido algo con el video TrEgZCndFBc
# 403
# Ha ocurrido algo con el video 199Am3Dvwvg
# 403
# Ha ocurrido algo con el video ZRZkh1Rvl8M
# 403
# Ha ocurrido algo con el video Tsd0xtDW_cA
# 403
# Ha ocurrido algo con el video NKvFGTW_nGE
# 403
# Ha ocurrido algo con el video 1IrzDvo6E9Y
# 403
# Ha ocurrido algo con el video Elj6Niavql8
# 403
# Ha ocurrido algo con el video 8nRRKyjSj7E
# 403
# Ha ocurrido algo con el video 1d47q9U4EI
# 403
# Ha ocurrido algo con el video GdgK2nvYTc
# 403
# Ha ocurrido algo con el video EV1QHxw0uWE
# 403
# Ha ocurrido algo con el video dh0clhANpw
# 403
# Ha ocurrido algo con el video 5PpCfhEpHls
# 403
# Ha ocurrido algo con el video CKR-e1LbrAY
# 403
# Ha ocurrido algo con el video iI6MoZ8LWd0
# 403
# Ha ocurrido algo con el video YNNc0TuHp0s
# 403
# Ha ocurrido algo con el video N73pfZxlSY0
# 403
# Ha ocurrido algo con el video 71dZz31jxs
# 403
# Ha ocurrido algo con el video DRkhFz5qJ0Y
# 403
# Ha ocurrido algo con el video H-CH7dpfYa4
# 403
# Ha ocurrido algo con el video La4to8aa5Uo
# 403
# Ha ocurrido algo con el video Y-dAO5Nmuy8
# 403
# Ha ocurrido algo con el video TRN6tB7W4Hs
# 403
# Ha ocurrido algo con el video 9E31unbf8ls
# 403
# Ha ocurrido algo con el video Cs73YVBFhN8
# 403
# Ha ocurrido algo con el video OqTAUmBBg
# 403
# Ha ocurrido algo con el video CwcoY9OZV4g
# 403
# Ha ocurrido algo con el video F4FrDNYEm4U
# 403
# Ha ocurrido algo con el video x225ycR6DJI
# 403
# Ha ocurrido algo con el video TZvz0ghpyuo
# 403
# Ha ocurrido algo con el video 4KrX1i_X9B8
# 403
# Ha ocurrido algo con el video QUMO1kd5Z0M
# 403
# Ha ocurrido algo con el video WdDqXksGJN4
# 403
# Ha ocurrido algo con el video 0XC7LErFIlw
# 403
# Ha ocurrido algo con el video jDTQvAh55WI
# 403
# Ha ocurrido algo con el video IBNYA762IxI
# 403
# Ha ocurrido algo con el video SAnF_niT8eQ
# 403
# Ha ocurrido algo con el video DcYVwCEIMaM
# 403
# Ha ocurrido algo con el video d9Zt9Fg5Ej4
# 403
# Ha ocurrido algo con el video PSamOCPLazI
# 403
# Ha ocurrido algo con el video CIacZtQdhSo
# 403
# Ha ocurrido algo con el video SdMGdLiIVXE
# 403
# Ha ocurrido algo con el video UQOG6d5byzg
# 403
# Ha ocurrido algo con el video N6mbsbiwxho
# 403
# Ha ocurrido algo con el video Zrkf7fIu4Es
# 403
# Ha ocurrido algo con el video 35G06oaN8A4
# 403
# Ha ocurrido algo con el video Wagvs6XUUo
# 403
# Ha ocurrido algo con el video Bqy3k7EaTyQ
# 403
# Ha ocurrido algo con el video qBcai1893PE
# 403
# Ha ocurrido algo con el video J0RW_mDzvKs
# 403
# Ha ocurrido algo con el video 0Uf4RAAI
# 403
# Ha ocurrido algo con el video KYAg50M5qOs
# 403
# Ha ocurrido algo con el video q4T2OG2F7k8
# 403
# Ha ocurrido algo con el video GfytvL1BA8
# 403
# Ha ocurrido algo con el video C4WVzirxjoc
# 403
# Ha ocurrido algo con el video g0uwtfID3Qs
# 403
# Ha ocurrido algo con el video LPbK2whgak4
# 403
# Ha ocurrido algo con el video r_PJPm8fZkE
# 403
# Ha ocurrido algo con el video z2WDciaxXNI
# 403
# Ha ocurrido algo con el video EJl0vfdSX8
# 403
# Ha ocurrido algo con el video XroIWcGrd0A
# 403
# Ha ocurrido algo con el video 54rekTg46PY
# 403
# Ha ocurrido algo con el video A74vj917K60
# 403
# Ha ocurrido algo con el video iDPqzNZ3xMU
# 403
# Ha ocurrido algo con el video 3hxHMRtPQAo
# 403
# Ha ocurrido algo con el video JXlN_i-AU
# 403
# Ha ocurrido algo con el video krT83_eyt_8
# 403
# Ha ocurrido algo con el video HgfGAGsRII
# 403
# Ha ocurrido algo con el video BsDSrhYESwc
# 403
# Ha ocurrido algo con el video F03ZqvEzbU
# 403
# Ha ocurrido algo con el video dF4D05fQai4
# 403
# Ha ocurrido algo con el video S3U-WZ7BaU
# 403
# Ha ocurrido algo con el video NLOsFTZKzE
# 403
# Ha ocurrido algo con el video LvOIpRiEePQ
# 403
# Ha ocurrido algo con el video AUKz5md2EzM
# 403
# Ha ocurrido algo con el video xI8QZrrYK6s
# 403
# Ha ocurrido algo con el video IVcLpTlD0bM
# 403
# Ha ocurrido algo con el video YEWXBA81FdE
# 403
# Ha ocurrido algo con el video XJpHvwn5rs
# 403
# Ha ocurrido algo con el video YJpv5bNCYx8
# 403
# Ha ocurrido algo con el video B_egBVUshpE
# 403
# Ha ocurrido algo con el video PV-Ap-cNXQA
# 403
# Ha ocurrido algo con el video SSZ1dLPkj4
# 403
# Ha ocurrido algo con el video _N3T1JcFTs4
# 403
# Ha ocurrido algo con el video YKVRkYkO_n4
# 403
# Ha ocurrido algo con el video nQuoLcBPU
# 403
# Ha ocurrido algo con el video ST1862a0
# 403
# Ha ocurrido algo con el video dC8g7B7c1S4
# 403
# Ha ocurrido algo con el video X3u8Bp6wg
# 403
# Ha ocurrido algo con el video RdG_WwLvVl0
# 403
# Ha ocurrido algo con el video ztCKH2V19uw
# 403
# Ha ocurrido algo con el video R4WAGfu4m9A
# 403
# Ha ocurrido algo con el video 8E5_2CXZqQ
# 403
# Ha ocurrido algo con el video BcX2FFuBufI
# 403
# Ha ocurrido algo con el video X5ISMa17B-c
# 403
# Ha ocurrido algo con el video 245RR7NAlyk
# 403
# Ha ocurrido algo con el video NN3xHRmdHgQ
# 403
# Ha ocurrido algo con el video FGOkF3zZN5I
# 403
# Ha ocurrido algo con el video 8ulDHnZbE3E
# 403
# Ha ocurrido algo con el video qbMEQE7JQaw
# 403
# Ha ocurrido algo con el video DBkN8LArYw
# 403
# Ha ocurrido algo con el video DRDJHFqkpQM
# 403
# Ha ocurrido algo con el video 3hmMXXQ4QzQ
# 403
# Ha ocurrido algo con el video 1zxaA2u0jLk
# 403
# Ha ocurrido algo con el video JJEE-XWoQ
# 403
# Ha ocurrido algo con el video -Uax8yJ0SaU
# 403
# Ha ocurrido algo con el video 3uzf8NlDx6o
# 403
# Ha ocurrido algo con el video 4bZT-rjHn0
# 403
# Ha ocurrido algo con el video _uFakjiSnk
# 403
# ...
# 403
# Ha ocurrido algo con el video UhdYrDSQi_o
# 403
# Ha ocurrido algo con el video AXgBgoLHOts
# 403
# Ha ocurrido algo con el video 7a2INzcmIA
# 403
# Ha ocurrido algo con el video 0COKX79sCg
# 403
# Ha ocurrido algo con el video xiNrdNAGw
# 403
# Ha ocurrido algo con el video Isg-NLbYllk
# 403
# Ha ocurrido algo con el video jN2NP1d4RNo
# 403
# Ha ocurrido algo con el video NC5TzyzM6qo
# 403
# Ha ocurrido algo con el video qEjnEXCzHA
# 403
# Ha ocurrido algo con el video MT_rHllmZ_M
# 403
# Ha ocurrido algo con el video qlYyGVZTQ
# 403
# Ha ocurrido algo con el video LzQKECnVKkY
# 403
# Ha ocurrido algo con el video Uy1RXPwMc
# 403
# Ha ocurrido algo con el video HjiX1cBiGtg
# 403
# Ha ocurrido algo con el video _jXxF8R35O8
# 403
# Ha ocurrido algo con el video KOj-IwZ0Do
# 403
# Ha ocurrido algo con el video YT1gsq_wpsc
# 403
# Ha ocurrido algo con el video MkPL3XH5PfE
# 403
# Ha ocurrido algo con el video 2MzLNpqkXZA
# 403
# Ha ocurrido algo con el video PcL_G1UyI4s
# 403
# Ha ocurrido algo con el video -Z0u-qVlMmY
# 403
# Ha ocurrido algo con el video YnVZSXTUAw
# 403
# Ha ocurrido algo con el video LrF_i51pTI
# 403
# Ha ocurrido algo con el video Seu1LAwEXc
# 403
# Ha ocurrido algo con el video 9HTbfdmLwkw
# 403
# Ha ocurrido algo con el video DdDqQg_aew
# 403
# Ha ocurrido algo con el video RtbwF5xv4pc
# 403
# Ha ocurrido algo con el video -QVrNELAFlI
# 403
# Ha ocurrido algo con el video iz5xjTdkvA
# 403
# Ha ocurrido algo con el video 6rL-Bs5aug
# 403
# Ha ocurrido algo con el video jWAGr7MQzk
# 403
# Ha ocurrido algo con el video IhhimU7pYGk
# 403
# Ha ocurrido algo con el video 2YsnpvAs5b8
# 403
# Ha ocurrido algo con el video OSi197itYI
# 403
# Ha ocurrido algo con el video k5W4AJfABIQ
# 403
# Ha ocurrido algo con el video CbDrLazP0qc
# 403
# Ha ocurrido algo con el video T5A9dmPZImc
# 403
# Ha ocurrido algo con el video XYNFWIGKCo
# 403
# Ha ocurrido algo con el video lUbTQO8A4
# 403
# Ha ocurrido algo con el video G4vB1SJgpyE
# 403
# Ha ocurrido algo con el video DmB8u8atNwU
# 403
# Ha ocurrido algo con el video na24Hv5iu-g
# 403
# Ha ocurrido algo con el video D10HZrmgfic
# 403
# Ha ocurrido algo con el video rEUaGlBT1Z8
# 403
# Ha ocurrido algo con el video G1hRKvdl14
# 403
# Ha ocurrido algo con el video ZeHAOEr2yE
# 403
# Ha ocurrido algo con el video 225BIYacdNw
# 403
# Ha ocurrido algo con el video MQTZpeOYM
# 403
# Ha ocurrido algo con el video 3PQ54TZD4
# 403
# Ha ocurrido algo con el video kCKyHWvurz0
# 403
# Ha ocurrido algo con el video N6qZO7J2YFQ
# 403
# Ha ocurrido algo con el video Dpf07sNlNgY
# 403
# Ha ocurrido algo con el video _BR5PqhWqFc
# 403
# Ha ocurrido algo con el video CXBN0Kyrqzo
# 403
# Ha ocurrido algo con el video PyGlgOm4m9Q
# 403
# Ha ocurrido algo con el video DihpJjWn8Rg
# 403
# Ha ocurrido algo con el video HZTjkQQLoYI
# 403
# Ha ocurrido algo con el video 89y2pSRmEE8
# 403
# Ha ocurrido algo con el video qwLk84SHuA
# 403
# Ha ocurrido algo con el video 59gweCYbpOU
# 403
# Ha ocurrido algo con el video 7cPErPHODM
# 403
# Ha ocurrido algo con el video 76x3_KyJfE
# 403
# Ha ocurrido algo con el video lra4hSvBcDE
# 403
# Ha ocurrido algo con el video -snSsr4NJMg
# 403
# Ha ocurrido algo con el video KP38r66gkdk
# 403
# Ha ocurrido algo con el video KXjX0AXtfA8
# 403
# Ha ocurrido algo con el video Ew9mARckdBc
# 403
# Ha ocurrido algo con el video dLPfFB4FPwo
# 403
# Ha ocurrido algo con el video jDfl_OqUEw
# 403
# Ha ocurrido algo con el video 1FznJKSQpE
# 403
# Ha ocurrido algo con el video HxAln1iJSPk
# 403
# Ha ocurrido algo con el video lzQ3crWGLdI
# 403
# Ha ocurrido algo con el video IIrEk7liu4g
# 403
# Ha ocurrido algo con el video d1atP1fL7w
# 403
# Ha ocurrido algo con el video HejLjfOfbcw
# 403
# Ha ocurrido algo con el video N2yz4XIoek0
# 403
# Ha ocurrido algo con el video Xo3Q85VU
# 403
# Ha ocurrido algo con el video RaBOjHqvu7k
# 403
# Ha ocurrido algo con el video CmJOyiHa5HA
# 403
# Ha ocurrido algo con el video Jxl2K9hWReo
# 403
# Ha ocurrido algo con el video AztmLdhGk
# 403
# Ha ocurrido algo con el video OArwzbJUYJ0
# 403
# Ha ocurrido algo con el video xtNhuSYOkmw
# 403
# Ha ocurrido algo con el video ig7WwWJQAxk
# 403
# Ha ocurrido algo con el video U4o3_Hees9U
# 403
# Ha ocurrido algo con el video zYDPjPqjik
# 403
# Ha ocurrido algo con el video XCKupfd11qw
# 403
# Ha ocurrido algo con el video kcjs8EgGxUU
# 403
# Ha ocurrido algo con el video jqxYMTpQ_fQ
# 403
# Ha ocurrido algo con el video KIB4LjRew-o
# 403
# Ha ocurrido algo con el video xCB4eZexmoA
# 403
# Ha ocurrido algo con el video SJgpkrUB4C0
# 403
# Ha ocurrido algo con el video I06KsbI2X9k
# 403
# Ha ocurrido algo con el video Cc49w0cs0Pk
# 403
# Ha ocurrido algo con el video APzGnSKRbZA
# 403
# Ha ocurrido algo con el video Fi4kOmEvPo
# 403
# Ha ocurrido algo con el video JJ9ejwzqEkw
# 403
# Ha ocurrido algo con el video WDYpEu0fuLM
# 403
# Ha ocurrido algo con el video xFQg7-aJxXI
# 403
# Ha ocurrido algo con el video kUuimJ3fto
# 403
# Ha ocurrido algo con el video 55oBZWP-TCg
# 403
# Ha ocurrido algo con el video 7zkmFoQ23-4
# 403
# Ha ocurrido algo con el video MBR3FXGWDWg
# 403
# Ha ocurrido algo con el video YPlkIfRz0
# 403
# Ha ocurrido algo con el video VZmgdKTLslM
# 403
# Ha ocurrido algo con el video U6AeLThhX7A
# 403
# Ha ocurrido algo con el video WZNjotkaAw
# 403
# Ha ocurrido algo con el video SIMGK8eTuDI
# 403
# Ha ocurrido algo con el video TKmn5toa0ss
# 403
# Ha ocurrido algo con el video 03mwNgPtDmM
# 403
# Ha ocurrido algo con el video F7v8qf5_S34
# 403
# Ha ocurrido algo con el video YHwoOFe0aDM
# 403
# Ha ocurrido algo con el video ACvLzmkK5MU
# 403
# Ha ocurrido algo con el video 9dC7HWuhEWQ
# 403
# Ha ocurrido algo con el video KbFqp27sllo
# 403
# Ha ocurrido algo con el video FauKqr5QDaM
# 403
# Ha ocurrido algo con el video TdUhDXaWcVU
# 403
# Ha ocurrido algo con el video rB07Rz3aq3k
# 403
# Ha ocurrido algo con el video 8FobFbS1eYo
# 403
# Ha ocurrido algo con el video xynVaSt7iL8
# 403
# Ha ocurrido algo con el video qpUNF-UyIrM
# 403
# Ha ocurrido algo con el video jN0dQZWdOIs
# 403
# Ha ocurrido algo con el video ialK_hYSCSY
# 403
# Ha ocurrido algo con el video Miha81DMJk
# 403
# Ha ocurrido algo con el video UCTKlS4iHIc
# 403
# Ha ocurrido algo con el video i0uwYqr7nak
# 403
# Ha ocurrido algo con el video QElj4D_NT3o
# 403
# Ha ocurrido algo con el video q74vlie0qE
# 403
# Ha ocurrido algo con el video _UlsmNdkYB0
# 403
# Ha ocurrido algo con el video Utrcecj9nPk
# 403
# Ha ocurrido algo con el video qhEEX7JK82c
# 403
# Ha ocurrido algo con el video 9zzyQToYgNM
# 403
# Ha ocurrido algo con el video 230uI4b6P98
# 403
# Ha ocurrido algo con el video GBzcPpM0E48
# 403
# Ha ocurrido algo con el video MiEBu89O_L0
# 403
# Ha ocurrido algo con el video iiXuMaljTE
# 403
# Ha ocurrido algo con el video qgB1XOrlhwY
# 403
# Ha ocurrido algo con el video iNn4B8U83sE
# 403
# Ha ocurrido algo con el video JV7BGsAyUcs
# 403
# Ha ocurrido algo con el video rcmPtZMi954
# 403
# Ha ocurrido algo con el video T097qm--8
# 403
# Ha ocurrido algo con el video fc1fyRZkUO8
# 403
# Ha ocurrido algo con el video 6DfPz6Ju6fc
# 403
# Ha ocurrido algo con el video GbrdSuYaZpc
# 403
# Ha ocurrido algo con el video 69V-Y5kr1O8
# 403
# Ha ocurrido algo con el video 6MFz2ONjHXw
# 403
# Ha ocurrido algo con el video J4TB7FmaPtQ
# 403
# Ha ocurrido algo con el video Nu6dxhR5m0
# 403
# Ha ocurrido algo con el video C0PhZPTEHlA
# 403
# Ha ocurrido algo con el video 3Td_TNKxAEU
# 403
# Ha ocurrido algo con el video 2TrAuD5knSc
# 403
# Ha ocurrido algo con el video 19aK10kzadQ
# 403
# Ha ocurrido algo con el video Ie75mSaLLVQ
# 403
# Ha ocurrido algo con el video ffz9nlaFTSg
# 403
# Ha ocurrido algo con el video OakEYm9X64Q
# 403
# Ha ocurrido algo con el video HNKwYCX_fqg
# 403
# Ha ocurrido algo con el video zOANaDIsZOA
# 403
# Ha ocurrido algo con el video KwIJbRHptV4
# 403
# Ha ocurrido algo con el video kDEo80HS4
# 403
# Ha ocurrido algo con el video N76hRNFbFZ0
# 403
# Ha ocurrido algo con el video 1tWfFMhMlLE
# 403
# Ha ocurrido algo con el video Hj7SNI_AtQg
# 403
# Ha ocurrido algo con el video AXB2-KnUc9Y
# 403
# Ha ocurrido algo con el video HfC2BW0n7s8
# 403
# Ha ocurrido algo con el video 86sd5v6Qr7I
# 403
# Ha ocurrido algo con el video JbPisecTK_o
# 403
# Ha ocurrido algo con el video GQHqKJ7wWLM
# 403
# Ha ocurrido algo con el video 4Mk2LqJz8Lk
# 403
# Ha ocurrido algo con el video DD3KsZCPbzU
# 403
# Ha ocurrido algo con el video GBt7gpgL0Bg
# 403
# Ha ocurrido algo con el video HcQsvuDXyw8
# 403
# Ha ocurrido algo con el video KnNZWY2pV10
# 403
# Ha ocurrido algo con el video gfuarr43A
# 403
# Ha ocurrido algo con el video 2EYiE398sjU
# 403
# Ha ocurrido algo con el video VSgUM7blNEs
# 403
# Ha ocurrido algo con el video N7-311-MFuQ
# 403
# Ha ocurrido algo con el video BlB5pG0ItWw
# 403
# Ha ocurrido algo con el video qKLnHi8Syic
# 403
# Ha ocurrido algo con el video 2c45muzuoVo
# 403
# Ha ocurrido algo con el video 4s7FzETUMEs
# 403
# Ha ocurrido algo con el video EL-1eBOBEgQ
# 403
# Ha ocurrido algo con el video durSAY5mR8o
# 403
# Ha ocurrido algo con el video Z10h-Ihg
# 403
# Ha ocurrido algo con el video rMGwfExFPAw
# 403
# Ha ocurrido algo con el video CuwqZcDGlAc
# 403
# Ha ocurrido algo con el video GCOhFSOU_08
# 403
# Ha ocurrido algo con el video Cs878vnrVAk
# 403
# Ha ocurrido algo con el video HxIfkjqjSKY
# 403
# Ha ocurrido algo con el video Uw9UfIGolMM
# 403
# Ha ocurrido algo con el video lDtaBKgPyyA
# 403
# Ha ocurrido algo con el video kDHmUdyyr8s
# 403
# Ha ocurrido algo con el video EP3LdQh4vM
# 403
# Ha ocurrido algo con el video MZISROHVVU
# 403
# Ha ocurrido algo con el video 6X7Kekd-m2Y
# 403
# Ha ocurrido algo con el video 8881N-M7Dhs
# 403
# Ha ocurrido algo con el video MC9d5lrCfxQ
# 403
# Ha ocurrido algo con el video 80zE84ikHmY
# 403
# Ha ocurrido algo con el video WXkIKAyWpSU
# 403
# Ha ocurrido algo con el video jM97yPPnIHE
# 403
# Ha ocurrido algo con el video iS8URhgT0
# 403
# Ha ocurrido algo con el video 1mD1F3HXzMU
# 403
# Ha ocurrido algo con el video SCJus4hDi1E
# 403
# Ha ocurrido algo con el video RYoQl9YDKU
# 403
# Ha ocurrido algo con el video 0yfwfiMReCs
# 403
# Ha ocurrido algo con el video Rfj5W-JJWEA
# 403
# Ha ocurrido algo con el video fB_4Nsdlahc
# 403
# Ha ocurrido algo con el video VBYV8G1ImdQ
# 403
# Ha ocurrido algo con el video EDbZonrYR68
# 403
# Ha ocurrido algo con el video l4jtlaFgwwA
# 403
# Ha ocurrido algo con el video nQ1p6v9n8Gw
# 403
# Ha ocurrido algo con el video i7psI1lSb4g
# 403
# Ha ocurrido algo con el video qlyg0vTMBZA
# 403
# Ha ocurrido algo con el video Sa44EbasDs4
# 403
# Ha ocurrido algo con el video Zf0buFTb6F0
# 403
# Ha ocurrido algo con el video GRke5oZIejY
# 403
# Ha ocurrido algo con el video S8bTWf5Gk0s
# 403
# Ha ocurrido algo con el video 3hcusEumaI
# 403
# Ha ocurrido algo con el video -l0koL2OyYo
# 403
# Ha ocurrido algo con el video OnFmTGXDWzo
# 403
# Ha ocurrido algo con el video H3Xnrhr3Zs
# 403
# Ha ocurrido algo con el video L_PRHUDmQgU
# 403
# Ha ocurrido algo con el video Rj44rMy-EWQ
# 403
# Ha ocurrido algo con el video 83bOipGfI
# 403
# Ha ocurrido algo con el video xqmWGFwYwlw
# 403
# Ha ocurrido algo con el video PF66kAd5nqY
# 403
# Ha ocurrido algo con el video UMEI9oyr2c
# 403
# Ha ocurrido algo con el video neWOqiNrxvo
# 403
# Ha ocurrido algo con el video X6RKRFaHB6w
# 403
# Ha ocurrido algo con el video EBpuMhwmck0
# 403
# Ha ocurrido algo con el video 8WI1S6TWDJY
# 403
# Ha ocurrido algo con el video Ui8I_cPAMcc
# 403
# Ha ocurrido algo con el video NIzPtk963Lo
# 403
# Ha ocurrido algo con el video JNpV97qxJ28
# 403
# Ha ocurrido algo con el video UhVzcHQzW1k
# 403
# Ha ocurrido algo con el video ROK683yXD-I
# 403
# Ha ocurrido algo con el video nB_EQWqWA5o
# 403
# Ha ocurrido algo con el video PgFY4mPT8-s
# 403
# Ha ocurrido algo con el video MugyCrk3bZc
# 403
# Ha ocurrido algo con el video UQvVtwKtAX8
# 403
# Ha ocurrido algo con el video Axxz7DYfEss
# 403
# Ha ocurrido algo con el video 1GBJkohTIM0
# 403
# Ha ocurrido algo con el video TRocASDyOt0
# 403
# Ha ocurrido algo con el video ghyO19sXqPE
# 403
# Ha ocurrido algo con el video 7Ejozx3Q1E
# 403
# Ha ocurrido algo con el video qzxRRUSSb8
# 403
# Ha ocurrido algo con el video QlcCl3HFr0k
# 403
# Ha ocurrido algo con el video NGeUZpJcwM
# 403
# Ha ocurrido algo con el video BCdUZpiFc2w
# 403
# Ha ocurrido algo con el video UPsYdsjRJrM
# 403
# Ha ocurrido algo con el video FL5fEv52CWo
# 403
# Ha ocurrido algo con el video k4Yic_6g93Q
# 403
# Ha ocurrido algo con el video gegtLFSEhDw
# 403
# Ha ocurrido algo con el video PGjr9Gf5ONo
# 403
# Ha ocurrido algo con el video V-qzJGQMpSY
# 403
# Ha ocurrido algo con el video nQfIFQHIaUY
# 403
# Ha ocurrido algo con el video jZZPfllD4Y
# 403
# Ha ocurrido algo con el video Os3gkm5DjfE
# 403
# Ha ocurrido algo con el video 5fcuI4GpReE
# 403
# Ha ocurrido algo con el video RCSSnQsWd9w
# 403
# Ha ocurrido algo con el video LUcFNIsoWuo
# 403
# Ha ocurrido algo con el video 6lIr2Hl1As
# 403
# Ha ocurrido algo con el video iEwjua8bJxM
# 403
# Ha ocurrido algo con el video EaEOQqcldf8
# 403
# Ha ocurrido algo con el video CI9DK1AYhc
# 403
# Ha ocurrido algo con el video 5RIcZBTipSc
# 403
# Ha ocurrido algo con el video EU1RNYTF32U
# 403
# Ha ocurrido algo con el video RluX-0XaE
# 403
# Ha ocurrido algo con el video i6qFqgxzYfI
# 403
# Ha ocurrido algo con el video 7i7rZ2HcxkY
# 403
# Ha ocurrido algo con el video dLML0AJ7Rv8
# 403
# Ha ocurrido algo con el video 2FEAuew4R4
# 403
# Ha ocurrido algo con el video P6YxVQSWRTg
# 403
# Ha ocurrido algo con el video TZgm2_gPXJA
# 403
# Ha ocurrido algo con el video qKnQmogbdX0
# 403
# Ha ocurrido algo con el video 7m-wt9W-CZQ
# 403
# Ha ocurrido algo con el video _7tHbrvzpnU
# 403
# Ha ocurrido algo con el video N4mn1R2jXWA
# 403
# Ha ocurrido algo con el video Dsmq5fecjh4
# 403
# Ha ocurrido algo con el video NMfBygdxZ2U
# 403
# Ha ocurrido algo con el video nw_YUuzWr_E
# 403
# Ha ocurrido algo con el video fI5IRaEFa0U
# 403
# Ha ocurrido algo con el video OAo4HPGPIA0
# 403
# Ha ocurrido algo con el video laVyHMRaj1Q
# 403
# Ha ocurrido algo con el video B9Vx62LDYTQ
# 403
# Ha ocurrido algo con el video VohV9XN_4W8
# 403
# Ha ocurrido algo con el video QeJkmI_ZHk
# 403
# Ha ocurrido algo con el video 77WJbC7OsQw
# 403
# Ha ocurrido algo con el video 5yzDIp_j1XE
# 403
# Ha ocurrido algo con el video iTS0Y7l7VBA
# 403
# Ha ocurrido algo con el video JqWpyGcg
# 403
# Ha ocurrido algo con el video ng2n024OVc
# 403
# Ha ocurrido algo con el video j3B7pUlUSWo
# 403
# Ha ocurrido algo con el video 07D3OkHhI
# 403
# Ha ocurrido algo con el video 4gqkLTnuiAI
# 403
# Ha ocurrido algo con el video zlXDfL5tvA0
# 403
# Ha ocurrido algo con el video qpZw8etSjfg
# 403
# Ha ocurrido algo con el video 7RMnyU2FkjQ
# 403
# Ha ocurrido algo con el video E9Oi3SWJArA
# 403
# Ha ocurrido algo con el video JXynYmo2cYo
# 403
# Ha ocurrido algo con el video PU_vheZAeeQ
# 403
# Ha ocurrido algo con el video VfnQUS2l0U
# 403
# Ha ocurrido algo con el video XjTr47VEQE
# 403
# Ha ocurrido algo con el video f5BZJO81UOE
# 403
# Ha ocurrido algo con el video LcOrNYaue10
# 403
# Ha ocurrido algo con el video 3O2vNBZULMk
# 403
# Ha ocurrido algo con el video zkAE12oLlak
# 403
# Ha ocurrido algo con el video KHhUK5CT7HU
# 403
# Ha ocurrido algo con el video 8M7isTJT1yc
# 403
# Ha ocurrido algo con el video 8ri2B4u3tM
# 403
# Ha ocurrido algo con el video 2dt_w1C4
# 403
# Ha ocurrido algo con el video MuvYxPGlny0
# 403
# Ha ocurrido algo con el video lHiFG-EN_zU
# 403
# Ha ocurrido algo con el video 3fhrXmZF4
# 403
# Ha ocurrido algo con el video 8kB8mjhmhHc
# 403
# Ha ocurrido algo con el video fVUlVep8pU0
# 403
# Ha ocurrido algo con el video jQTkzXP3ef0
# 403
# Ha ocurrido algo con el video YRZTgMu1GiY
# 403
# Ha ocurrido algo con el video i2X0BooU2TI
# 403
# Ha ocurrido algo con el video XEJneYv32Zg
# 403
# Ha ocurrido algo con el video LgEAIymLJPI
# 403
# Ha ocurrido algo con el video 5UGkijQ8s4c
# 403
# Ha ocurrido algo con el video 9IRL9C3G_tM
# 403
# Ha ocurrido algo con el video TSof7_ZdSU8
# 403
# Ha ocurrido algo con el video VYBuflH6VUM
# 403
# Ha ocurrido algo con el video nOd8QgWDFQ
# 403
# Ha ocurrido algo con el video lTsCOGZzf18
# 403
# Ha ocurrido algo con el video 19E-Bd3Skk
# 403
# Ha ocurrido algo con el video 1jk-uR7tEX4
# 403
# Ha ocurrido algo con el video WVHiFIh8Av8
# 403
# Ha ocurrido algo con el video VwCJ3T8uPk
# 403
# Ha ocurrido algo con el video ApaVaXy90
# 403
# Ha ocurrido algo con el video 60mm0bhPrG8
# 403
# Ha ocurrido algo con el video 76QAJ1vsOLI
# 403
# Ha ocurrido algo con el video nfyNFl61XY
# 403
# Ha ocurrido algo con el video 0b_pYKrgk
# 403
# Ha ocurrido algo con el video X8GqBZ__46o
# 403
# Ha ocurrido algo con el video 3iyQUIUnQX4
# 403
# Ha ocurrido algo con el video 0o-Z7gjScYc
# 403
# Ha ocurrido algo con el video CInrpR8GW1Q
# 403
# Ha ocurrido algo con el video Q4ExNStlyc
# 403
# Ha ocurrido algo con el video qKFFZycDRI
# 403
# Ha ocurrido algo con el video n7ki-COMP4Q
# 403
# Ha ocurrido algo con el video f5hu1jv7OI4
# 403
# Ha ocurrido algo con el video 8xXB6k71M8U
# 403
# Ha ocurrido algo con el video gkEZdP8KI64
# 403
# Ha ocurrido algo con el video rmFRAKOAPP8
# 403
# Ha ocurrido algo con el video fUnjhxgw3A
# 403
# Ha ocurrido algo con el video W2kKq0MFn20
# 403
# Ha ocurrido algo con el video 3eGQTujYwc
# 403
# Ha ocurrido algo con el video J5I-5eo_vDM

# %% [markdown]
# ### Cleaning YT

# %%
df1 = pd.read_csv("../data/youtube/api/lol_1_raw")
df2 = pd.read_csv("../data/youtube/api/lol_2_raw")
df = pd.concat([df1, df2], axis = 0)

# %%
df.to_csv("lol_raw")

# %%
sp.cleaning("../data/youtube/api/csgo_raw", "csgo")
